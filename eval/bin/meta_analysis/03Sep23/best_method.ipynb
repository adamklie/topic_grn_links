# %% [markdown]
# # Set-up

# %%
import os
import sys
import glob
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
from PyComplexHeatmap import *

# %%
# visualization settings
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

plt.rcParams['figure.figsize'] = [6, 4.5]
plt.rcParams["savefig.dpi"] = 300

# %%
results_dir = "/cellar/users/aklie/projects/igvf/topic_grn_links/eval/results"
dataset_name = "meta_analysis"
in_date = "03Sep23"

# %% [markdown]
# # GRN metadata

# %%
# Read in all the network metadata
grn_metadata_df = pd.read_csv(os.path.join(results_dir, dataset_name, in_date, "cleaned_grn_metadata.tsv"), sep="\t", index_col=0)

# %%
grn_metadata_df = grn_metadata_df[(grn_metadata_df["genotype"] != "both") & (grn_metadata_df["method"] == "celloracle") & (grn_metadata_df["normalization"] == "pf_log1p_pf") & (grn_metadata_df["dataset"] == "igvf_b01_LeftCortex")]
len(grn_metadata_df)
# Out:
# 2

# %% [markdown]
# # TF metadata

# %%
# Read in the metadata
tf_metadata_df = pd.read_csv(os.path.join(results_dir, dataset_name, in_date, "tf_metadata_topics_baselines.tsv"), sep="\t", index_col=0)
len(tf_metadata_df)
# Out:
# 709

# %%
# Sort by presence in literature
tf_metadata_df = tf_metadata_df.sort_values(by="in_literature", ascending=False)
tf_metadata_df.head()
# Out:
#        in_scenic  in_aracne  in_celloracle  in_literature  number_grns  \
# Mef2a       True       True           True           True           93
# Runx1       True      False           True           True           76
# Mef2c       True       True           True           True           87
# Stat3       True       True           True           True           43
# Sall1       True       True          False           True           29
#
#        in_topics  in_igvf_b01_LeftCortex  in_Bridge_Satpathy  in_both  \
# Mef2a       True                    True                True     True
# Runx1       True                    True                True     True
# Mef2c       True                    True                True     True
# Stat3       True                    True                True     True
# Sall1       True                    True                True     True
#
#        in_neither
# Mef2a       False
# Runx1       False
# Mef2c       False
# Stat3       False
# Sall1       False

# %% [markdown]
# # TF network scores

# %%
# Read in the network scores
tf_scores_df = pd.read_csv(os.path.join(results_dir, dataset_name, in_date, "tf_only_network_scores.tsv"), sep="\t").rename(columns={"Unnamed: 0": "tf_name"})
tf_scores_df.head()
# Out:
#    tf_name  degree_all  degree_centrality_all  degree_in  \
# 0  Runx1t1           2               0.004866          0
# 1  Runx1t1          50               0.142045          2
# 2  Runx1t1          37               0.099196          1
# 3  Runx1t1           1               0.001031          1
# 4  Runx1t1           1               0.001211          1
#
#    degree_centrality_in  degree_out  degree_centrality_out  \
# 0              0.000000           2               0.004866
# 1              0.005682          48               0.136364
# 2              0.002681          36               0.096515
# 3              0.001031           0               0.000000
# 4              0.001211           0               0.000000
#
#    betweenness_centrality  eigenvector_centrality  \
# 0                     0.0                0.005795
# 1                    81.0                0.226653
# 2                    24.0                0.183886
# 3                     0.0                0.014566
# 4                     0.0                0.015317
#
#                                             grn_name
# 0  Bridge_Satpathy_aracne_balanced_genotype_micro...
# 1  Bridge_Satpathy_aracne_balanced_genotype_micro...
# 2  Bridge_Satpathy_aracne_balanced_genotype_micro...
# 3  Bridge_Satpathy_celloracle_balanced_genotype_m...
# 4  Bridge_Satpathy_celloracle_balanced_genotype_m...

# %%
# Check to make sure all the tfs in the scores are in the metadata
(~tf_scores_df.tf_name.isin(tf_metadata_df.index)).sum()
# Out:
# 0

# %%
# Subset to scores that are in the metadata
tf_scores_df = tf_scores_df[tf_scores_df.grn_name.isin(grn_metadata_df.index)]
tf_scores_df["grn_name"].unique()
# Out:
# array(['igvf_b01_LeftCortex_celloracle_balanced_genotype_microglia_B6J_0.05_pf_log1p_pf',
#        'igvf_b01_LeftCortex_celloracle_balanced_genotype_microglia_CASTJ_0.05_pf_log1p_pf'],
#       dtype=object)

# %%
# Normalize the scores to between 0 and 1
cols_to_normalize = ['degree_all', 'degree_centrality_all', 'degree_in', 'degree_centrality_in', 'degree_out', 'degree_centrality_out', 'betweenness_centrality', 'eigenvector_centrality']
tf_scores_df[cols_to_normalize] = tf_scores_df[cols_to_normalize].apply(lambda x: (x - x.min()) / (x.max() - x.min()), axis=0)
tf_scores_df.head()
# Out:
#     tf_name  degree_all  degree_centrality_all  degree_in  \
# 152     Zfx    0.107692               0.103309        0.0
# 153     Zfx    0.123077               0.123618        0.0
# 240    Klf7    0.261538               0.250894        0.0
# 241    Klf7    0.246154               0.246619        0.0
# 343   Nr1d2    0.061538               0.059034        0.0
#
#      degree_centrality_in  degree_out  degree_centrality_out  \
# 152                   0.0    0.129032               0.123857
# 153                   0.0    0.145161               0.145161
# 240                   0.0    0.290323               0.278679
# 241                   0.0    0.274194               0.274194
# 343                   0.0    0.080645               0.077411
#
#      betweenness_centrality  eigenvector_centrality  \
# 152                     0.0                0.042900
# 153                     0.0                0.048213
# 240                     0.0                0.112184
# 241                     0.0                0.194964
# 343                     0.0                0.030733
#
#                                               grn_name
# 152  igvf_b01_LeftCortex_celloracle_balanced_genoty...
# 153  igvf_b01_LeftCortex_celloracle_balanced_genoty...
# 240  igvf_b01_LeftCortex_celloracle_balanced_genoty...
# 241  igvf_b01_LeftCortex_celloracle_balanced_genoty...
# 343  igvf_b01_LeftCortex_celloracle_balanced_genoty...

# %% [markdown]
# # Dot plot across metrics

# %%
grn_1 = "igvf_b01_LeftCortex_celloracle_balanced_genotype_microglia_CASTJ_0.05_pf_log1p_pf"
grn_2 = "igvf_b01_LeftCortex_celloracle_balanced_genotype_microglia_B6J_0.05_pf_log1p_pf"

# %%
# Keep only tf_names that appear in separate rows for each of grn_names
tf_scores_df = tf_scores_df.groupby("tf_name").filter(lambda x: len(x) == 2)
tf_scores_df.head()
# Out:
#     tf_name  degree_all  degree_centrality_all  degree_in  \
# 152     Zfx    0.107692               0.103309        0.0
# 153     Zfx    0.123077               0.123618        0.0
# 240    Klf7    0.261538               0.250894        0.0
# 241    Klf7    0.246154               0.246619        0.0
# 343   Nr1d2    0.061538               0.059034        0.0
#
#      degree_centrality_in  degree_out  degree_centrality_out  \
# 152                   0.0    0.129032               0.123857
# 153                   0.0    0.145161               0.145161
# 240                   0.0    0.290323               0.278679
# 241                   0.0    0.274194               0.274194
# 343                   0.0    0.080645               0.077411
#
#      betweenness_centrality  eigenvector_centrality  \
# 152                     0.0                0.042900
# 153                     0.0                0.048213
# 240                     0.0                0.112184
# 241                     0.0                0.194964
# 343                     0.0                0.030733
#
#                                               grn_name
# 152  igvf_b01_LeftCortex_celloracle_balanced_genoty...
# 153  igvf_b01_LeftCortex_celloracle_balanced_genoty...
# 240  igvf_b01_LeftCortex_celloracle_balanced_genoty...
# 241  igvf_b01_LeftCortex_celloracle_balanced_genoty...
# 343  igvf_b01_LeftCortex_celloracle_balanced_genoty...

# %%
# Get the top tf_name based difference[metric] difference between two remaining grn_name groups
tfs_to_plot = set()
for metric in cols_to_normalize:

    # Get the difference between the two grn_names for each tf_name
    ec_diff = tf_scores_df.groupby("tf_name").apply(lambda x: x[x.grn_name == grn_1][metric].values[0] - x[x.grn_name == grn_2][metric].values[0])

    # Make a dataframe from the series
    ec_diff_df = pd.DataFrame(ec_diff).rename(columns={0: "ec_diff"})

    # Add in the sign of the difference
    ec_diff_df["sign"] = np.sign(ec_diff_df["ec_diff"])

    # Replace sign with up or down
    ec_diff_df["sign"] = ec_diff_df["sign"].replace({1: "CASTJ", -1: "B6J"})

    # Add in absolute value of the difference
    ec_diff_df["abs_ec_diff"] = np.abs(ec_diff_df["ec_diff"])

    # Sort by absolute value of the difference
    ec_diff_df = ec_diff_df.sort_values(by="abs_ec_diff", ascending=False)

    # Add the top 25
    tfs_to_plot.update(set(ec_diff_df.head(10).index))

# %%
metric = "eigenvector_centrality"

# Get the difference between the two grn_names for each tf_name
ec_diff = tf_scores_df.groupby("tf_name").apply(lambda x: x[x.grn_name == grn_1][metric].values[0] - x[x.grn_name == grn_2][metric].values[0])

# Make a dataframe from the series
ec_diff_df = pd.DataFrame(ec_diff).rename(columns={0: "ec_diff"})

# Add in the sign of the difference
ec_diff_df["sign"] = np.sign(ec_diff_df["ec_diff"])

# Replace sign with up or down
ec_diff_df["sign"] = ec_diff_df["sign"].replace({1: "CASTJ", -1: "B6J"})

# Add in absolute value of the difference
ec_diff_df["abs_ec_diff"] = np.abs(ec_diff_df["ec_diff"])

# Sort by absolute value of the difference
ec_diff_df = ec_diff_df.sort_values(by="abs_ec_diff", ascending=False)

# %%
len(tfs_to_plot)
# Out:
# 29

# %%
tf_metadata_df = ec_diff_df.loc[tfs_to_plot].merge(tf_metadata_df, left_index=True, right_index=True)
# Out:
# /tmp/ipykernel_763421/113715477.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   tf_metadata_df = ec_diff_df.loc[tfs_to_plot].merge(tf_metadata_df, left_index=True, right_index=True)

# %%
data = tf_scores_df[tf_scores_df.tf_name.isin(tf_metadata_df.index)]

# %%
# Need to create long dataframe with ["betweenness_centrality", "eigenvector_centrality" as values
data = data.melt(id_vars=["tf_name", "grn_name"], value_vars=cols_to_normalize, var_name="metric", value_name="score")
data["ID"] = data["grn_name"] + "-" + data["metric"]
data = data.merge(grn_metadata_df.reset_index()[["grn_name", "dataset", "genotype"]], on="grn_name")
data.head()
# Out:
#   tf_name                                           grn_name      metric  \
# 0    Rora  igvf_b01_LeftCortex_celloracle_balanced_genoty...  degree_all
# 1   Bach2  igvf_b01_LeftCortex_celloracle_balanced_genoty...  degree_all
# 2    Smc3  igvf_b01_LeftCortex_celloracle_balanced_genoty...  degree_all
# 3    Rbpj  igvf_b01_LeftCortex_celloracle_balanced_genoty...  degree_all
# 4   Nfkb1  igvf_b01_LeftCortex_celloracle_balanced_genoty...  degree_all
#
#       score                                                 ID  \
# 0  0.707692  igvf_b01_LeftCortex_celloracle_balanced_genoty...
# 1  0.138462  igvf_b01_LeftCortex_celloracle_balanced_genoty...
# 2  0.400000  igvf_b01_LeftCortex_celloracle_balanced_genoty...
# 3  0.507692  igvf_b01_LeftCortex_celloracle_balanced_genoty...
# 4  0.200000  igvf_b01_LeftCortex_celloracle_balanced_genoty...
#
#                dataset genotype
# 0  igvf_b01_LeftCortex      B6J
# 1  igvf_b01_LeftCortex      B6J
# 2  igvf_b01_LeftCortex      B6J
# 3  igvf_b01_LeftCortex      B6J
# 4  igvf_b01_LeftCortex      B6J

# %%
# Create row annotation dataframe
df_cols = data.set_index("ID")[["metric", "genotype"]]

# Deduplicate
df_cols = df_cols[~df_cols.index.duplicated(keep='first')]

# Order by metric
df_cols = df_cols.sort_values(by="metric", ascending=False)

# Head
df_cols.head()
# Out:
#                                                                     metric  \
# ID
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  eigenvector_centrality
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  eigenvector_centrality
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...              degree_out
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...              degree_out
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...               degree_in
#
#                                                    genotype
# ID
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...      B6J
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...    CASTJ
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...      B6J
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...    CASTJ
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...      B6J

# %%
# Create col annotation dataframe
df_rows = tf_metadata_df[["in_literature", "sign"]].replace({True: "Yes", False: "No"})
df_rows
# Out:
#        in_literature   sign
# Elf1              No    B6J
# Foxn3             No  CASTJ
# Zbtb20            No  CASTJ
# Fli1              No    B6J
# Mef2c            Yes    B6J
# Setdb1            No    B6J
# Rora              No    B6J
# Nfkb1             No    B6J
# Nfatc3            No    B6J
# Klf12             No  CASTJ
# E2f3              No    B6J
# Thrb              No    B6J
# Rbpj              No  CASTJ
# Bach2             No  CASTJ
# Ikzf1             No    B6J
# Zmiz1             No  CASTJ
# Rreb1             No    B6J
# Zeb1              No  CASTJ
# Pbx1              No    B6J
# Ets1              No  CASTJ
# Irf2              No    B6J
# Git2              No  CASTJ
# Hivep2            No    B6J
# Esrrg             No    B6J
# Runx1            Yes  CASTJ
# Smc3              No    B6J
# Nfia              No    B6J
# Mef2a            Yes    B6J
# Irf8             Yes    B6J

# %%
df_rows.index.isin(tf_metadata_df.index).sum()
# Out:
# 29

# %%
# Column annotations
col_ha = HeatmapAnnotation(
    Metric=anno_simple(df_cols.metric, legend=False, cmap="Set1", add_text=True),
    Genotype=anno_simple(df_cols.genotype, legend=False, cmap="Dark2", add_text=True),
    verbose=0,label_side='left',label_kws={'horizontalalignment':'right'},
)

# %%
# Row annotations
row_ha = HeatmapAnnotation(
    Sign=anno_simple(df_rows.sign, legend=False, cmap="Dark2"),
    label=anno_label(df_rows.sign, merge=True,rotation=0, cmap="Dark2"),
    axis=0,verbose=0,label_kws={'rotation':45,'horizontalalignment':'left'}
)

# %%
df_rows
# Out:
#        in_literature   sign
# Elf1              No    B6J
# Foxn3             No  CASTJ
# Zbtb20            No  CASTJ
# Fli1              No    B6J
# Mef2c            Yes    B6J
# Setdb1            No    B6J
# Rora              No    B6J
# Nfkb1             No    B6J
# Nfatc3            No    B6J
# Klf12             No  CASTJ
# E2f3              No    B6J
# Thrb              No    B6J
# Rbpj              No  CASTJ
# Bach2             No  CASTJ
# Ikzf1             No    B6J
# Zmiz1             No  CASTJ
# Rreb1             No    B6J
# Zeb1              No  CASTJ
# Pbx1              No    B6J
# Ets1              No  CASTJ
# Irf2              No    B6J
# Git2              No  CASTJ
# Hivep2            No    B6J
# Esrrg             No    B6J
# Runx1            Yes  CASTJ
# Smc3              No    B6J
# Nfia              No    B6J
# Mef2a            Yes    B6J
# Irf8             Yes    B6J

# %%
# Plot the heatmap
plt.figure(figsize=(12, 5))
cm = DotClustermapPlotter(
    data=data,
    x="ID",
    y="tf_name",
    value="score",
    c='score',
    cmap='Blues',
    show_rownames=True,
    row_cluster=False,
    col_cluster=False,
    top_annotation=col_ha,
    right_annotation=row_ha,
    col_split=df_cols.metric,
    col_split_gap=1,
    row_split=df_rows.sign,
    row_split_gap=1
)
plt.savefig("/cellar/users/aklie/projects/igvf/topic_grn_links/external/igvf_annual_meetings/2023/genotype_dotplot.pdf")
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Collecting legends..
# Plotting legends..

# %% [markdown]
# # Select GRNs to compare across genotypes

# %%
method = "celloracle"
normalization = "pf_log1p_pf"
#selected_metadata = grn_metadata_df
selected_metadata = grn_metadata_df.query("method == @method and normalization == @normalization")

# %%
links_dict = {}
for i, (grn_name, row) in tqdm(enumerate(selected_metadata.iterrows()), total=len(selected_metadata)):
    links_df = pd.read_csv(row["filtered_links_path"], sep="\t")
    links_df["coef"] = links_df["weight_signed"]
    links_df["coef_abs"] = links_df["weight_unsigned"]
    links_dict[grn_name] = links_df
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]

# %%
# Make a celloracle links object
links = co.Links(name="celloracle_pf_log1p_pf_cross_genotype_microglia_comparison", links_dict=links_dict)

# %%
# Filter to top 2000 links
links.filter_links(weight="weight_unsigned", p=None, threshold_number=2000)

# %%
# Calculate network scores.
links.get_network_score()

# %%
# Save gene scores for each gene in the network
gene_scores = links.merged_score

# %%
selected_metadata
# Out:
#                                                                 dataset  \
# grn_name
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  igvf_b01_LeftCortex
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  igvf_b01_LeftCortex
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  igvf_b01_LeftCortex
# Bridge_Satpathy_celloracle_balanced_genotype_mi...      Bridge_Satpathy
# Bridge_Satpathy_celloracle_balanced_genotype_mi...      Bridge_Satpathy
# Bridge_Satpathy_celloracle_balanced_genotype_mi...      Bridge_Satpathy
#
#                                                         method  \
# grn_name
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  celloracle
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  celloracle
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  celloracle
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  celloracle
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  celloracle
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  celloracle
#
#                                                                           cells  \
# grn_name
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  balanced_genotype_microglia
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  balanced_genotype_microglia
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  balanced_genotype_microglia
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  balanced_genotype_microglia
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  balanced_genotype_microglia
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  balanced_genotype_microglia
#
#                                                     genes normalization  \
# grn_name
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...   0.05   pf_log1p_pf
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...   0.05   pf_log1p_pf
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...   0.05   pf_log1p_pf
# Bridge_Satpathy_celloracle_balanced_genotype_mi...   0.05   pf_log1p_pf
# Bridge_Satpathy_celloracle_balanced_genotype_mi...   0.05   pf_log1p_pf
# Bridge_Satpathy_celloracle_balanced_genotype_mi...   0.05   pf_log1p_pf
#
#                                                    genotype  \
# grn_name
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...      B6J
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...    CASTJ
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...     both
# Bridge_Satpathy_celloracle_balanced_genotype_mi...      B6J
# Bridge_Satpathy_celloracle_balanced_genotype_mi...    CASTJ
# Bridge_Satpathy_celloracle_balanced_genotype_mi...     both
#
#                                                     scale_free_topology_score  \
# grn_name
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...                   0.889136
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...                   0.878897
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...                   0.835246
# Bridge_Satpathy_celloracle_balanced_genotype_mi...                   0.807120
# Bridge_Satpathy_celloracle_balanced_genotype_mi...                   0.844570
# Bridge_Satpathy_celloracle_balanced_genotype_mi...                   0.851157
#
#                                                     mean_connectivity  \
# grn_name
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...           5.340454
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...           5.563282
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...           5.471956
# Bridge_Satpathy_celloracle_balanced_genotype_mi...           5.427408
# Bridge_Satpathy_celloracle_balanced_genotype_mi...           5.738881
# Bridge_Satpathy_celloracle_balanced_genotype_mi...           6.379585
#
#                                                     median_connectivity  \
# grn_name
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...                  3.0
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...                  3.0
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...                  3.0
# Bridge_Satpathy_celloracle_balanced_genotype_mi...                  3.0
# Bridge_Satpathy_celloracle_balanced_genotype_mi...                  2.0
# Bridge_Satpathy_celloracle_balanced_genotype_mi...                  2.0
#
#                                                     max_connectivity  \
# grn_name
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...              57.0
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...              66.0
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...             193.0
# Bridge_Satpathy_celloracle_balanced_genotype_mi...             197.0
# Bridge_Satpathy_celloracle_balanced_genotype_mi...             185.0
# Bridge_Satpathy_celloracle_balanced_genotype_mi...             237.0
#
#                                                     number_tfs  \
# grn_name
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...         182
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...         177
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...         172
# Bridge_Satpathy_celloracle_balanced_genotype_mi...         189
# Bridge_Satpathy_celloracle_balanced_genotype_mi...         188
# Bridge_Satpathy_celloracle_balanced_genotype_mi...         150
#
#                                                                                   filtered_links_path  \
# grn_name
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  /cellar/users/aklie/projects/igvf/topic_grn_li...
#
#                                                                            degree_centrality_out_path  \
# grn_name
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  /cellar/users/aklie/projects/igvf/topic_grn_li...
#
#                                                                           eigenvector_centrality_path  \
# grn_name
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  /cellar/users/aklie/projects/igvf/topic_grn_li...
#
#                                                                           betweenness_centrality_path  \
# grn_name
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  /cellar/users/aklie/projects/igvf/topic_grn_li...
#
#                                                                                              ulm_path  \
# grn_name
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  /cellar/users/aklie/projects/igvf/topic_grn_li...
#
#                                                                                            viper_path  \
# grn_name
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  /cellar/users/aklie/projects/igvf/topic_grn_li...
#
#                                                                                           aucell_path
# grn_name
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# igvf_b01_LeftCortex_celloracle_balanced_genotyp...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  /cellar/users/aklie/projects/igvf/topic_grn_li...
# Bridge_Satpathy_celloracle_balanced_genotype_mi...  /cellar/users/aklie/projects/igvf/topic_grn_li...

# %%
# assign a color to each key in links_dict based on a seaborn palette
palette = sns.color_palette('Paired', len(links_dict))
links.palette = pd.DataFrame({'key': links_dict.keys(), 'palette': palette}).set_index('key')

# %%
# Cross genotype, same algorithm
links.plot_score_comparison_2D(
    value="eigenvector_centrality",
    cluster1="igvf_b01_LeftCortex_celloracle_balanced_genotype_microglia_B6J_0.05_pf_log1p_pf", 
    cluster2="igvf_b01_LeftCortex_celloracle_balanced_genotype_microglia_CASTJ_0.05_pf_log1p_pf",
    percentile=98
)

# %%
# Cross genotype, same algorithm
links.plot_score_comparison_2D(
    value="eigenvector_centrality",
    cluster1="Bridge_Satpathy_celloracle_balanced_genotype_microglia_B6J_0.05_pf_log1p_pf", 
    cluster2="Bridge_Satpathy_celloracle_balanced_genotype_microglia_CASTJ_0.05_pf_log1p_pf",
    percentile=98
)

# %%
# Cross genotype, same algorithm
links.plot_score_comparison_2D(
    value="betweenness_centrality",
    cluster1="Bridge_Satpathy_celloracle_balanced_genotype_microglia_both_0.05_pf_log1p_pf", 
    cluster2="igvf_b01_LeftCortex_celloracle_balanced_genotype_microglia_both_0.05_pf_log1p_pf",
    percentile=98
)

# %%
# Grab a list of the tfs in the literature
lit_tfs = tf_metadata_df[tf_metadata_df["in_literature"]].index

# %%
for tf in lit_tfs:
    # Certain genes
    links.plot_score_per_cluster(goi=tf)
# Out:
# Mef2a
# Runx1
# Mef2c
# Stat3
# Sall1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[49], line 3
#       1 for tf in lit_tfs:
#       2     # Certain genes
# ----> 3     links.plot_score_per_cluster(goi=tf)
#
# File ~/opt/miniconda3/envs/celloracle/lib/python3.8/site-packages/celloracle/network_analysis/links_object.py:367, in Links.plot_score_per_cluster(self, goi, save, plt_show)
#     355 """
#     356 Plot network score for a gene.
#     357 This function visualizes the network score for a specific gene between clusters to get an insight into the dynamics of the gene.
#    (...)
#     363        Plots will not be saved if [save=None]. Default is None.
#     364 """
#     365 self._get_network_score_if_not_exist()
# --> 367 plot_score_per_cluster(links=self, goi=goi, save=save, plt_show=plt_show)
#
# File ~/opt/miniconda3/envs/celloracle/lib/python3.8/site-packages/celloracle/network_analysis/gene_analysis.py:320, in plot_score_per_cluster(links, goi, save, plt_show)
#     318 for i, value in zip([1, 2, 3], values):
#     319     plt.subplot(1, 3,  i)
# --> 320     ax = sns.stripplot(data=res, y="cluster", x=value,
#     321                   size=10, orient="h",linewidth=1, edgecolor="w",
#     322                   order=links.palette.index.values,
#     323                   palette=dict(links.palette.palette))
#     324     ax.spines['right'].set_visible(False)
#     325     ax.spines['top'].set_visible(False)
#
# File ~/opt/miniconda3/envs/celloracle/lib/python3.8/site-packages/seaborn/categorical.py:2537, in stripplot(data, x, y, hue, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, native_scale, formatter, legend, ax, **kwargs)
#    2529 size = kwargs.get("s", size)
#    2531 kwargs.update(dict(
#    2532     s=size ** 2,
#    2533     edgecolor=edgecolor,
#    2534     linewidth=linewidth)
#    2535 )
# -> 2537 p.plot_strips(
#    2538     jitter=jitter,
#    2539     dodge=dodge,
#    2540     color=color,
#    2541     edgecolor=edgecolor,
#    2542     plot_kws=kwargs,
#    2543 )
#    2545 # XXX this happens inside a plotting method in the distribution plots
#    2546 # but maybe it's better out here? Alternatively, we have an open issue
#    2547 # suggesting that _attach could add default axes labels, which seems smart.
#    2548 p._add_axis_labels(ax)
#
# File ~/opt/miniconda3/envs/celloracle/lib/python3.8/site-packages/seaborn/categorical.py:283, in _CategoricalPlotterNew.plot_strips(self, jitter, dodge, color, edgecolor, plot_kws)
#     280 ax = self.ax
#     281 dodge_move = jitter_move = 0
# --> 283 for sub_vars, sub_data in self.iter_data(iter_vars,
#     284                                          from_comp_data=True,
#     285                                          allow_empty=True):
#     286     if offsets is not None and (offsets != 0).any():
#     287         dodge_move = offsets[sub_data["hue"].map(self._hue_map.levels.index)]
#
# File ~/opt/miniconda3/envs/celloracle/lib/python3.8/site-packages/seaborn/_oldcore.py:1044, in VectorPlotter.iter_data(self, grouping_vars, reverse, from_comp_data, by_facet, allow_empty, dropna)
#    1038 if self.var_types[axis] == "categorical":
#    1039     if self._var_ordered[axis]:
#    1040         # If the axis is ordered, then the axes in a possible
#    1041         # facet grid are by definition "shared", or there is a
#    1042         # single axis with a unique cat -> idx mapping.
#    1043         # So we can just take the first converter object.
# -> 1044         converter = self.converters[axis].iloc[0]
#    1045         levels[axis] = converter.convert_units(levels[axis])
#    1046     else:
#    1047         # Otherwise, the mappings may not be unique, but we can
#    1048         # use the unique set of index values in comp_data.
#
# File ~/opt/miniconda3/envs/celloracle/lib/python3.8/site-packages/pandas/core/indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/opt/miniconda3/envs/celloracle/lib/python3.8/site-packages/pandas/core/indexing.py:1625, in _iLocIndexer._getitem_axis(self, key, axis)
#    1622     raise TypeError("Cannot index by location index with a non-integer key")
#    1624 # validate the location
# -> 1625 self._validate_integer(key, axis)
#    1627 return self.obj._ixs(key, axis=axis)
#
# File ~/opt/miniconda3/envs/celloracle/lib/python3.8/site-packages/pandas/core/indexing.py:1557, in _iLocIndexer._validate_integer(self, key, axis)
#    1555 len_axis = len(self.obj._get_axis(axis))
#    1556 if key >= len_axis or key < -len_axis:
# -> 1557     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds
