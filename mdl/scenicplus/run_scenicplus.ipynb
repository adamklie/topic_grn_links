# %% [markdown]
# # SCENIC+: Pipeline

# %% [markdown]
# This notebooks attempts to outline all the steps required to go from multiome data to eGRNs.

# %% [markdown]
# # SCENIC+: Step-by-step multiome analysis

# %% [markdown]
# ## 1. Set-up
# As a starting point, we need fragment files for sc/snATAC-seq data and something that can be read into AnnData for sc/snRNA-seq data.

# %%
import os
import sys
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)
_stderr = sys.stderr
null = open(os.devnull,'wb')

# %% [markdown]
# Set the working directory for dumping files and reading files

# %%
results_dir = "/cellar/users/aklie/projects/igvf/topic_grn_links/grn_inference/celloracle/results"
dataset_name = "CharacterizationMcGinnis_Dataset6"

# %% [markdown]
# Either download or check that you have fragment files for your data. These are often in `tsv.gz` format.

# %%
# !ls -lh /cellar/users/aklie/data/igvf/topic_grn_links/mouse_heart/encode/fragments
# Out:
# total 33K
# drwxr-xr-x 3 aklie carter-users   1 Jan  5 10:03 ENCFF035SPT
# drwxr-xr-x 3 aklie carter-users   1 Jan  5 10:03 ENCFF042ZJI
# drwxr-xr-x 3 aklie carter-users   1 Jan  5 10:04 ENCFF101BLM
# drwxr-xr-x 3 aklie carter-users   1 Jan  5 10:04 ENCFF119IVK
# drwxr-xr-x 3 aklie carter-users   1 Jan  5 10:04 ENCFF176LJV
# drwxr-xr-x 3 aklie carter-users   1 Jan  5 10:04 ENCFF187VMN
# drwxr-xr-x 3 aklie carter-users   1 Jan  5 10:04 ENCFF622EUO
# drwxr-xr-x 3 aklie carter-users   1 Jan  5 10:05 ENCFF683IBE
# -rw-r--r-- 1 aklie carter-users 29K Jan  5 09:55 metadata.tsv

# %% [markdown]
# Either download or check that you have a file or set of files that can be read into a scanpy anndata object

# %%
# !ls -lh /cellar/users/aklie/data/igvf/topic_grn_links/mouse_heart/preprocess/snrna/filtered.h5ad
# Out:
# -rw-r--r-- 1 aklie carter-users 801M Jan 13 09:46 /cellar/users/aklie/data/igvf/topic_grn_links/mouse_adrenal/preprocess/snrna/filtered.h5ad

# %% [markdown]
# ## 2. scRNA-seq analysis

# %% [markdown]
# Set-up the directories for running a scRNA-seq analysis with scanpy. If you have already processed data you can skip this step. You will need a DataFrame with cell type labels as one of the columns to proceed.

# %%
import scanpy as sc

# Set some figure parameters for nice display inside jupyternotebooks.
# %matplotlib inline
sc.settings.set_figure_params(dpi=80, frameon=False, figsize=(5, 5), facecolor='white')

# Make a directory for to store the processed scRNA-seq data.
if not os.path.exists(os.path.join(work_dir, 'scRNA')):
    os.makedirs(os.path.join(work_dir, 'scRNA'))

# %% [markdown]
# For the ENCODE phase 4 mouse data, we have multiple cell type labels at our disposal.

# %%
adata = sc.read_h5ad(os.path.join(work_dir, 'data/adata_downsampled.h5ad'))
adata.var_names_make_unique()
adata
# Out:
# AnnData object with n_obs × n_vars = 7420 × 47721
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'cellID', 'doublet_scores', 'doublets', 'library_accession', 'technology', 'species', 'tissue', 'sex', 'timepoint', 'rep', 'sample', 'depth1', 'depth2', 'experiment', 'experiment_batch', 'integration_batch', 'run_number', 'experiment_accession', 'file_accession', 'lower_nCount_RNA', 'upper_nCount_RNA', 'lower_nFeature_RNA', 'upper_doublet_scores', 'upper_percent.mt', 'percent.mt', 'percent.ribo', 'nCount_SCT', 'nFeature_SCT', 'integrated_snn_res.1.6', 'seurat_clusters', 'predicted.id', 'prediction.score.Macrophages', 'prediction.score.Fibroblasts', 'prediction.score.Endothelial', 'prediction.score.Endocardial', 'prediction.score.Schwann_cells', 'prediction.score.Fibroblasts_Wif1.', 'prediction.score.Smooth_muscle', 'prediction.score.B_cells', 'prediction.score.Lymphatic_ECs', 'prediction.score.DC.like_cells', 'prediction.score.T_cells', 'prediction.score.Granulocytes', 'prediction.score.Cardiomyocytes', 'prediction.score.Epicardial', 'prediction.score.max', 'predictions', 'S.Score', 'G2M.Score', 'Phase', 'prediction.score.Smooth_muscle_cells', 'prediction.score.Ventricular_Cardiomyocyte', 'prediction.score.Pericytes', 'prediction.score.NotAssigned', 'prediction.score.Fibroblast', 'prediction.score.Adipocytes', 'prediction.score.Lymphoid', 'prediction.score.doublets', 'prediction.score.Myeloid', 'prediction.score.Neuronal', 'prediction.score.Atrial_Cardiomyocyte', 'prediction.score.Mesothelial', 'atlas_predictions', 'integrated_snn_res.2', 'atlas_celltypes', 'stressed_celltypes', 'subtypes', 'celltypes', 'gen_celltype', 'batch'
#     var: 'features'

# %% [markdown]
# ## 3. scATAC-seq analysis

# %% [markdown]
# Set-up for running a scATAC-seq analysis with pycisTopic.

# %%
import pycisTopic

#make a directory for to store the processed scRNA-seq data.
if not os.path.exists(os.path.join(work_dir, 'scATAC')):
    os.makedirs(os.path.join(work_dir, 'scATAC'))
tmp_dir = '/cellar/users/aklie/tmp/'

# %% [markdown]
# You will need to create a dictionary with values as paths to fragment files and keys as sample names.

# %%
import glob as glob
import pandas as pd

# Load in the paths to your fragment files and turn them into a dictionary
frag_files = glob.glob("/cellar/users/aklie/data/igvf/topic_grn_links/mouse_heart/encode/fragments/*/*/*/*/*/*.tsv.gz")
fragments_dict = dict(zip([file.split("/")[-6] for file in frag_files], frag_files))

# %% [markdown]
# Read in or grab the metadata from any previous methods for annotations

# %%
# Grab the metadata from the single cell anndata 
cell_data = adata.obs
del(adata)

# %%
cell_data["technology"].value_counts()
# Out:
# 10x    7420
# Name: technology, dtype: int64

# %%
# For the mouse ENCODE 4 data, only a subset of the cells were from the 10x multiome kit
cell_data = cell_data[cell_data["technology"] == "10x"]
cell_data['celltype'] = cell_data['celltypes'].astype(str) # set data type of the celltype column to str, otherwise the export_pseudobulk function will complain.
cell_data["celltype"].value_counts(dropna=False)
# Out:
# CE               1000
# CF               1000
# CM               1000
# Endocardial      1000
# Macrophages      1000
# Pericytes        1000
# Smooth_muscle     371
# Lymphatic_ECs     287
# Schwann_cells     275
# Lymphoid          248
# Epicardial        239
# Name: celltype, dtype: int64

# %% [markdown]
# Next you should make sure that you have barcodes in your cell metadata that match the barcodes in your fragment files. This can be tricky, but you can use the following as examples

# %%
# Read in some extra metadata to match cells to samples and toconvert barcodes
snatac_meta = pd.read_csv("/cellar/users/aklie/data/igvf/topic_grn_links/mouse_heart/encode/enc4_mouse_snatac_metadata.tsv", sep="\t")
acc_mp = snatac_meta.set_index("rna_library_accession")["file_accession"]
cell_data["sample_id"] = cell_data["library_accession"].map(acc_mp).values
cell_data["sample_id"].value_counts(dropna=False)
# Out:
# ENCFF151YWH    2054
# ENCFF135RXW    2006
# ENCFF087GPD    1747
# ENCFF152GXR    1613
# Name: sample_id, dtype: int64

# %% [markdown]
# Map the RNA barcodes from the anndata to the ATAC barcodes present in the fragment file

# %%
# Map the RNA barcodes from the anndata to the ATAC barcodes present in the fragment file
rna_bcs = pd.read_csv("/cellar/users/aklie/data/igvf/topic_grn_links/mouse_adrenal/encode/gene_exp_737K-arc-v1.txt", header=None)[0].values # read in the set of external rna barcodes
atac_bcs = pd.read_csv("/cellar/users/aklie/data/igvf/topic_grn_links/mouse_adrenal/encode/atac_737K-arc-v1.txt", header=None)[0].values # Read in the set of external atac barcodes
bcs = pd.DataFrame(data={"rna_bcs": rna_bcs, "atac_bcs": atac_bcs}) # create a dataframe with both
COMPLEMENT_DNA = {"A": "T", "C": "G", "G": "C", "T": "A"} # the fragment files contain reverse complements of the atac bcs, need to get these
bcs["atac_bcs_rc"] = ["".join(COMPLEMENT_DNA.get(base, base) for base in reversed(bc)) for bc in bcs["atac_bcs"]]
bc_map = bcs.set_index("rna_bcs")["atac_bcs_rc"] # create a map for going from rna bcs to atac bcs in fragment files

# %%
# Map the rna bcs in the cell metadata to the fragment file atac barcodes
cell_data["rna_bc"] = [row[0] for row in cell_data["cellID"].str.split(".")] # grab the RNA barcodes from the anndata metadata
cell_data["atac_bc"] = cell_data["rna_bc"].map(bc_map) # map the
cell_data["sample_id"] = cell_data["sample_id"].astype(str)
cell_data["atac_bc_sample"] = cell_data["atac_bc"] + "-" + cell_data["sample_id"]
cell_data["barcode"] = cell_data["atac_bc"]
cell_data = cell_data.set_index("atac_bc")

# %%
# Run a quick sanity check to make sure your barcodes match up
test_fragments = pd.read_csv(fragments_dict["ENCFF087GPD"], sep="\t", header=None)
test_cell_data = cell_data[cell_data["sample_id"] == "ENCFF087GPD"]
len(test_cell_data), test_cell_data["barcode"].isin(test_fragments[3]).sum()

# %% [markdown]
# We also need chromosome sizes in order to export to pseudobulk and to call peaks. Read these in. Make sure you choose the correct species for your data!

# %%
import pyranges as pr
import requests

# Stream directly into memory using pandas
target_url='https://hgdownload.cse.ucsc.edu/goldenpath/mm10/bigZips/mm10.chrom.sizes'
chromsizes=pd.read_csv(target_url, sep='\t', header=None)
chromsizes.columns=['Chromosome', 'End']
chromsizes['Start']=[0]*chromsizes.shape[0]
chromsizes=chromsizes.loc[:,['Chromosome', 'Start', 'End']]
chromsizes=pr.PyRanges(chromsizes)

# %% [markdown]
# The next big step is to generate bed and bw files using all the fragments within each cell type. pycisTopic has a decent function for this that's a little finicky. A couple things to make sure of:
# - You have a "barcode" column with barcodes that match the barcodes in your fragment files
# - You have a "sample_id" column that maps cells to the samples contained in your fragment file dictionary
# - Your chromosomes in the chromsizes object you created match the chromsomes in your fragment files (make sure you have the right species)
# - You have enough total memory to handle ray's parallelization (if you use it)

# %%
from pycisTopic.pseudobulk_peak_calling import export_pseudobulk

# Run without ray since these are big files
bw_paths, bed_paths = export_pseudobulk(
    input_data = cell_data,
    variable = 'celltype', # variable by which to generate pseubulk profiles, in this case we want pseudobulks per celltype
    sample_id_col = 'sample_id',
    chromsizes = chromsizes,
    bed_path = os.path.join(work_dir, 'scATAC/consensus_peak_calling/pseudobulk_bed_files/'),  # specify where pseudobulk_bed_files should be stored
    bigwig_path = os.path.join(work_dir, 'scATAC/consensus_peak_calling/pseudobulk_bw_files/'), # specify where pseudobulk_bw_files should be stored
    path_to_fragments = fragments_dict, # location of fragment fiels
    n_cpu = 1, # specify the number of cores to use, we use ray for multi processing
    normalize_bigwig = True,
    remove_duplicates = True,
    _temp_dir = os.path.join(tmp_dir, 'ray_spill'),
    split_pattern = '-'
)
# Out:
# 2023-01-14 22:54:59,585 cisTopic     INFO     Reading fragments from /cellar/users/aklie/data/igvf/topic_grn_links/mouse_adrenal/encode/fragments/ENCFF187VMN/encode_scatac_dcc_2/results/ENCSR525WPH-1/fragments/fragments.tsv.gz
# 2023-01-14 22:56:44,138 cisTopic     INFO     Reading fragments from /cellar/users/aklie/data/igvf/topic_grn_links/mouse_adrenal/encode/fragments/ENCFF035SPT/encode_scatac_dcc_2/results/ENCSR713FPX-1/fragments/fragments.tsv.gz
# 2023-01-14 22:58:25,383 cisTopic     INFO     Reading fragments from /cellar/users/aklie/data/igvf/topic_grn_links/mouse_adrenal/encode/fragments/ENCFF622EUO/encode_scatac_dcc_2/results/ENCSR858YSB-1/fragments/fragments.tsv.gz
# 2023-01-14 23:00:24,434 cisTopic     INFO     Reading fragments from /cellar/users/aklie/data/igvf/topic_grn_links/mouse_adrenal/encode/fragments/ENCFF119IVK/encode_scatac_dcc_2/results/ENCSR400PXQ-1/fragments/fragments.tsv.gz
# 2023-01-14 23:01:55,753 cisTopic     INFO     Reading fragments from /cellar/users/aklie/data/igvf/topic_grn_links/mouse_adrenal/encode/fragments/ENCFF683IBE/encode_scatac_dcc_2/results/ENCSR668VPD-1/fragments/fragments.tsv.gz
# 2023-01-14 23:03:56,191 cisTopic     INFO     Reading fragments from /cellar/users/aklie/data/igvf/topic_grn_links/mouse_adrenal/encode/fragments/ENCFF042ZJI/encode_scatac_dcc_2/results/ENCSR736ABS-1/fragments/fragments.tsv.gz
# 2023-01-14 23:05:45,716 cisTopic     INFO     Reading fragments from /cellar/users/aklie/data/igvf/topic_grn_links/mouse_adrenal/encode/fragments/ENCFF176LJV/encode_scatac_dcc_2/results/ENCSR834NRP-1/fragments/fragments.tsv.gz
# 2023-01-14 23:07:43,911 cisTopic     INFO     Reading fragments from /cellar/users/aklie/data/igvf/topic_grn_links/mouse_adrenal/encode/fragments/ENCFF101BLM/encode_scatac_dcc_2/results/ENCSR024LKR-1/fragments/fragments.tsv.gz
# 2023-01-14 23:09:27,214 cisTopic     INFO     Creating pseudobulk for Adipocytes
# 2023-01-14 23:13:44,808 cisTopic     INFO     Adipocytes done!
# 2023-01-14 23:13:44,992 cisTopic     INFO     Creating pseudobulk for Capsule
# 2023-01-14 23:13:57,686 cisTopic     INFO     Capsule done!
# 2023-01-14 23:13:57,695 cisTopic     INFO     Creating pseudobulk for Cortex
# 2023-01-15 00:59:03,988 cisTopic     INFO     Cortex done!
# 2023-01-15 00:59:08,161 cisTopic     INFO     Creating pseudobulk for Endothelial
# 2023-01-15 01:12:19,987 cisTopic     INFO     Endothelial done!
# 2023-01-15 01:12:20,496 cisTopic     INFO     Creating pseudobulk for Fibroblast
# 2023-01-15 01:14:54,515 cisTopic     INFO     Fibroblast done!
# 2023-01-15 01:14:54,575 cisTopic     INFO     Creating pseudobulk for Hepatocyte
# 2023-01-15 01:15:01,065 cisTopic     INFO     Hepatocyte done!
# 2023-01-15 01:15:01,067 cisTopic     INFO     Creating pseudobulk for Macrophages
# 2023-01-15 01:16:52,776 cisTopic     INFO     Macrophages done!
# 2023-01-15 01:16:52,819 cisTopic     INFO     Creating pseudobulk for Medulla
# 2023-01-15 01:27:23,012 cisTopic     INFO     Medulla done!
# 2023-01-15 01:27:23,200 cisTopic     INFO     Creating pseudobulk for Skeletal_muscle
# 2023-01-15 01:27:27,106 cisTopic     INFO     Skeletal_muscle done!
# 2023-01-15 01:27:27,107 cisTopic     INFO     Creating pseudobulk for Smooth_muscle
# 2023-01-15 01:27:40,009 cisTopic     INFO     Smooth_muscle done!
# 2023-01-15 01:27:40,015 cisTopic     INFO     Creating pseudobulk for Sox10_
# 2023-01-15 01:28:20,816 cisTopic     INFO     Sox10_ done!
# 2023-01-15 01:28:20,827 cisTopic     INFO     Creating pseudobulk for Stromal
# 2023-01-15 01:32:55,037 cisTopic     INFO     Stromal done!

# %% [markdown]
# Dump the paths to the bed and bw files for peak calling

# %%
import pickle

# Export the paths
pickle.dump(
    bed_paths,
    open(os.path.join(work_dir, 'scATAC/consensus_peak_calling/pseudobulk_bed_files/bed_paths.pkl'), 'wb')
)
pickle.dump(
    bw_paths,
    open(os.path.join(work_dir, 'scATAC/consensus_peak_calling/pseudobulk_bw_files/bw_paths.pkl'), 'wb')
)

# %% [markdown]
# We can now run cell type specific peak calling using MACS2. pycisTopic has another useful function for this.

# %%
from pycisTopic.pseudobulk_peak_calling import peak_calling

# Run peak calling
macs_path='/cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2'
narrow_peaks_dict = peak_calling(
    macs_path,
    bed_paths,
    os.path.join(work_dir, 'scATAC/consensus_peak_calling/MACS/'),
    genome_size='hs',
    n_cpu=12,
    input_format='BEDPE',
    shift=73,
    ext_size=146,
    keep_dup = 'all',
    q_value = 0.05,
    _temp_dir = os.path.join(tmp_dir, 'ray_spill')
)
# Out:
# 2023-01-15 07:53:26,502	INFO worker.py:1519 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (macs_call_peak_ray pid=2044428) 2023-01-15 07:53:39,567 cisTopic     INFO     Calling peaks for Stromal with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Stromal.bed.gz --name Stromal  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044425) 2023-01-15 07:53:39,594 cisTopic     INFO     Calling peaks for Skeletal_muscle with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Skeletal_muscle.bed.gz --name Skeletal_muscle  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044422) 2023-01-15 07:53:39,605 cisTopic     INFO     Calling peaks for Capsule with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Capsule.bed.gz --name Capsule  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044427) 2023-01-15 07:53:39,579 cisTopic     INFO     Calling peaks for Medulla with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Medulla.bed.gz --name Medulla  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044431) 2023-01-15 07:53:39,584 cisTopic     INFO     Calling peaks for Smooth_muscle with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Smooth_muscle.bed.gz --name Smooth_muscle  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044421) 2023-01-15 07:53:39,669 cisTopic     INFO     Calling peaks for Cortex with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Cortex.bed.gz --name Cortex  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044430) 2023-01-15 07:53:39,663 cisTopic     INFO     Calling peaks for Fibroblast with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Fibroblast.bed.gz --name Fibroblast  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044423) 2023-01-15 07:53:39,654 cisTopic     INFO     Calling peaks for Sox10_ with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Sox10_.bed.gz --name Sox10_  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044429) 2023-01-15 07:53:39,679 cisTopic     INFO     Calling peaks for Macrophages with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Macrophages.bed.gz --name Macrophages  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044426) 2023-01-15 07:53:39,811 cisTopic     INFO     Calling peaks for Endothelial with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Endothelial.bed.gz --name Endothelial  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044424) 2023-01-15 07:53:39,810 cisTopic     INFO     Calling peaks for Hepatocyte with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Hepatocyte.bed.gz --name Hepatocyte  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044420) 2023-01-15 07:53:39,829 cisTopic     INFO     Calling peaks for Adipocytes with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Adipocytes.bed.gz --name Adipocytes  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044425) 2023-01-15 07:53:46,810 cisTopic     INFO     Skeletal_muscle done!
# (macs_call_peak_ray pid=2044424) 2023-01-15 07:53:48,470 cisTopic     INFO     Hepatocyte done!
# (macs_call_peak_ray pid=2044431) 2023-01-15 07:54:02,094 cisTopic     INFO     Smooth_muscle done!
# (macs_call_peak_ray pid=2044422) 2023-01-15 07:54:02,862 cisTopic     INFO     Capsule done!
# (macs_call_peak_ray pid=2044423) 2023-01-15 07:54:33,188 cisTopic     INFO     Sox10_ done!
# (macs_call_peak_ray pid=2044429) 2023-01-15 07:55:16,270 cisTopic     INFO     Macrophages done!
# (macs_call_peak_ray pid=2044430) 2023-01-15 07:56:03,457 cisTopic     INFO     Fibroblast done!
# (macs_call_peak_ray pid=2044428) 2023-01-15 07:56:38,317 cisTopic     INFO     Stromal done!
# (macs_call_peak_ray pid=2044420) 2023-01-15 07:56:49,962 cisTopic     INFO     Adipocytes done!
# (macs_call_peak_ray pid=2044427) 2023-01-15 07:59:06,210 cisTopic     INFO     Medulla done!
# (macs_call_peak_ray pid=2044426) 2023-01-15 07:59:19,057 cisTopic     INFO     Endothelial done!
# (macs_call_peak_ray pid=2044421) 2023-01-15 08:22:11,520 cisTopic     INFO     Cortex done!

# %%
# Dump the return object to a pickle
pickle.dump(
    narrow_peaks_dict,
    open(os.path.join(work_dir, 'scATAC/consensus_peak_calling/MACS/narrow_peaks_dict.pkl'), 'wb')
)

# %% [markdown]
# In order to generate a region x cell matrix, we need a consensus peak set. There a lot of ways to do this, again, pycisTopic has a couple functions that we will take advantage of

# %%
from pycisTopic.iterative_peak_calling import get_consensus_peaks

# %%
from pycisTopic.iterative_peak_calling import *

# Get consensus peaks
peak_half_width = 250
path_to_blacklist= os.path.join(work_dir, 'hg38-blacklist.v2.bed')
consensus_peaks=get_consensus_peaks(
    narrow_peaks_dict, 
    peak_half_width, 
    chromsizes=chromsizes, 
    path_to_blacklist=path_to_blacklist
)
# Out:
# 2023-01-15 08:22:15,531 cisTopic     INFO     Extending and merging peaks per class
# Warning! Start and End columns now have different dtypes: int64 and int32
# 2023-01-15 08:32:59,529 cisTopic     INFO     Done!

# %% [markdown]
# Save the consensus regions as a bed file. This will be used for multiple downstream steps

# %%
consensus_peaks.to_bed(
    path = os.path.join(work_dir, 'scATAC/consensus_peak_calling/consensus_regions.bed'),
    keep=True,
    compression='infer',
    chain=False
)

# %% [markdown]
# We can now perform QC on our scATAC data using the consensus peak set. We start by grabbing TSS annotations for protein coding genes. Again remember to choose the correct organism

# %%
import pybiomart as pbm

# Grab TSS annotations for mouse protein coding genes
dataset = pbm.Dataset(name='mmusculus_gene_ensembl',  host='http://www.ensembl.org')
annot = dataset.query(attributes=['chromosome_name', 'transcription_start_site', 'strand', 'external_gene_name', 'transcript_biotype'])
annot['Chromosome/scaffold name'] = annot['Chromosome/scaffold name'].to_numpy(dtype = str)
filter = annot['Chromosome/scaffold name'].str.contains('CHR|GL|JH|MT')
annot = annot[~filter]
annot['Chromosome/scaffold name'] = annot['Chromosome/scaffold name'].str.replace(r'(\b\S)', r'chr\1')
annot.columns=['Chromosome', 'Start', 'Strand', 'Gene', 'Transcript_type']
annot = annot[annot.Transcript_type == 'protein_coding']
# Out:
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pybiomart/dataset.py:269: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   result = pd.read_csv(StringIO(response.text), sep='\t')

# %%
# Each sample will have the same regions here as we want to merge
path_to_regions = dict.fromkeys(fragments_dict.keys(), os.path.join(work_dir, 'scATAC/consensus_peak_calling/consensus_regions.bed'))
path_to_regions
# Out:
# {'ENCFF187VMN': 'mouse_adrenal/scATAC/consensus_peak_calling/consensus_regions.bed',
#  'ENCFF035SPT': 'mouse_adrenal/scATAC/consensus_peak_calling/consensus_regions.bed',
#  'ENCFF622EUO': 'mouse_adrenal/scATAC/consensus_peak_calling/consensus_regions.bed',
#  'ENCFF119IVK': 'mouse_adrenal/scATAC/consensus_peak_calling/consensus_regions.bed',
#  'ENCFF683IBE': 'mouse_adrenal/scATAC/consensus_peak_calling/consensus_regions.bed',
#  'ENCFF042ZJI': 'mouse_adrenal/scATAC/consensus_peak_calling/consensus_regions.bed',
#  'ENCFF176LJV': 'mouse_adrenal/scATAC/consensus_peak_calling/consensus_regions.bed',
#  'ENCFF101BLM': 'mouse_adrenal/scATAC/consensus_peak_calling/consensus_regions.bed'}

# %% [markdown]
# Next is to calculate a set of metrics for each cell based on consensus regions. Note that this requires counting fragments again

# %%
from pycisTopic.qc import *

# Calculate QC stats for each sample
metadata_bc, profile_data_dict = compute_qc_stats(
    fragments_dict = fragments_dict,
    tss_annotation = annot,
    stats=['barcode_rank_plot', 'duplicate_rate', 'insert_size_distribution', 'profile_tss', 'frip'],
    label_list = None,
    path_to_regions = path_to_regions,
    n_cpu = 1,
    valid_bc = None,
    n_frag = 100,
    n_bc = None,
    tss_flank_window = 1000,
    tss_window = 50,
    tss_minimum_signal_window = 100,
    tss_rolling_window = 10,
    remove_duplicates = True,
    _temp_dir = os.path.join(tmp_dir + 'ray_spill')
)

# Dump the qc results in some objects
if not os.path.exists(os.path.join(work_dir, 'scATAC/quality_control')):
    os.makedirs(os.path.join(work_dir, 'scATAC/quality_control'))

pickle.dump(metadata_bc,
            open(os.path.join(work_dir, 'scATAC/quality_control/metadata_bc.pkl'), 'wb'))

pickle.dump(profile_data_dict,
            open(os.path.join(work_dir, 'scATAC/quality_control/profile_data_dict.pkl'), 'wb'))
# Out:
# 2023-01-15 09:05:14,033 cisTopic     INFO     Reading ENCFF187VMN
# 2023-01-15 09:06:44,590 cisTopic     INFO     Computing barcode rank plot for ENCFF187VMN
# 2023-01-15 09:06:44,591 cisTopic     INFO     Counting fragments
# 2023-01-15 09:06:50,918 cisTopic     INFO     Marking barcodes with more than 100
# 2023-01-15 09:06:50,969 cisTopic     INFO     Returning plot data
# 2023-01-15 09:06:50,973 cisTopic     INFO     Returning valid barcodes
# 2023-01-15 09:06:57,171 cisTopic     INFO     Computing duplicate rate plot for ENCFF187VMN
# 2023-01-15 09:07:05,086 cisTopic     INFO     Return plot data
# 2023-01-15 09:07:05,317 cisTopic     INFO     Computing insert size distribution for ENCFF187VMN
# 2023-01-15 09:07:05,319 cisTopic     INFO     Counting fragments
# 2023-01-15 09:07:06,860 cisTopic     INFO     Returning plot data
# 2023-01-15 09:07:56,480 cisTopic     INFO     Computing TSS profile for ENCFF187VMN
# 2023-01-15 09:08:05,050 cisTopic     INFO     Formatting annnotation
# 2023-01-15 09:08:05,102 cisTopic     INFO     Creating coverage matrix
# 2023-01-15 09:08:33,378 cisTopic     INFO     Coverage matrix done
# 2023-01-15 09:08:49,005 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# 2023-01-15 09:09:00,903 cisTopic     INFO     Returning normalized sample TSS enrichment data
# 2023-01-15 09:09:01,069 cisTopic     INFO     Computing FRIP profile for ENCFF187VMN
# 2023-01-15 09:09:03,023 cisTopic     INFO     Counting fragments
# 2023-01-15 09:09:14,962 cisTopic     INFO     Intersecting fragments with regions
# 2023-01-15 09:10:01,726 cisTopic     INFO     Sample ENCFF187VMN done!
# 2023-01-15 09:10:01,728 cisTopic     INFO     Reading ENCFF035SPT
# 2023-01-15 09:11:28,004 cisTopic     INFO     Computing barcode rank plot for ENCFF035SPT
# 2023-01-15 09:11:28,006 cisTopic     INFO     Counting fragments
# 2023-01-15 09:11:33,313 cisTopic     INFO     Marking barcodes with more than 100
# 2023-01-15 09:11:33,357 cisTopic     INFO     Returning plot data
# 2023-01-15 09:11:33,360 cisTopic     INFO     Returning valid barcodes
# 2023-01-15 09:11:37,878 cisTopic     INFO     Computing duplicate rate plot for ENCFF035SPT
# 2023-01-15 09:11:45,163 cisTopic     INFO     Return plot data
# 2023-01-15 09:11:45,338 cisTopic     INFO     Computing insert size distribution for ENCFF035SPT
# 2023-01-15 09:11:45,340 cisTopic     INFO     Counting fragments
# 2023-01-15 09:11:46,897 cisTopic     INFO     Returning plot data
# 2023-01-15 09:12:36,025 cisTopic     INFO     Computing TSS profile for ENCFF035SPT
# 2023-01-15 09:12:45,411 cisTopic     INFO     Formatting annnotation
# 2023-01-15 09:12:45,459 cisTopic     INFO     Creating coverage matrix
# 2023-01-15 09:13:13,605 cisTopic     INFO     Coverage matrix done
# 2023-01-15 09:13:24,395 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# 2023-01-15 09:13:32,375 cisTopic     INFO     Returning normalized sample TSS enrichment data
# 2023-01-15 09:13:32,542 cisTopic     INFO     Computing FRIP profile for ENCFF035SPT
# 2023-01-15 09:13:34,496 cisTopic     INFO     Counting fragments
# 2023-01-15 09:13:44,129 cisTopic     INFO     Intersecting fragments with regions
# 2023-01-15 09:14:25,542 cisTopic     INFO     Sample ENCFF035SPT done!
# 2023-01-15 09:14:25,543 cisTopic     INFO     Reading ENCFF622EUO
# 2023-01-15 09:16:05,951 cisTopic     INFO     Computing barcode rank plot for ENCFF622EUO
# 2023-01-15 09:16:05,953 cisTopic     INFO     Counting fragments
# 2023-01-15 09:16:11,914 cisTopic     INFO     Marking barcodes with more than 100
# 2023-01-15 09:16:11,960 cisTopic     INFO     Returning plot data
# 2023-01-15 09:16:11,964 cisTopic     INFO     Returning valid barcodes
# 2023-01-15 09:16:18,361 cisTopic     INFO     Computing duplicate rate plot for ENCFF622EUO
# 2023-01-15 09:16:26,781 cisTopic     INFO     Return plot data
# 2023-01-15 09:16:27,011 cisTopic     INFO     Computing insert size distribution for ENCFF622EUO
# 2023-01-15 09:16:27,013 cisTopic     INFO     Counting fragments
# 2023-01-15 09:16:28,821 cisTopic     INFO     Returning plot data
# 2023-01-15 09:17:28,724 cisTopic     INFO     Computing TSS profile for ENCFF622EUO
# 2023-01-15 09:17:39,992 cisTopic     INFO     Formatting annnotation
# 2023-01-15 09:17:40,042 cisTopic     INFO     Creating coverage matrix
# 2023-01-15 09:18:13,394 cisTopic     INFO     Coverage matrix done
# 2023-01-15 09:18:21,141 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# 2023-01-15 09:18:26,911 cisTopic     INFO     Returning normalized sample TSS enrichment data
# 2023-01-15 09:18:27,078 cisTopic     INFO     Computing FRIP profile for ENCFF622EUO
# 2023-01-15 09:18:29,009 cisTopic     INFO     Counting fragments
# 2023-01-15 09:18:43,220 cisTopic     INFO     Intersecting fragments with regions
# 2023-01-15 09:19:36,984 cisTopic     INFO     Sample ENCFF622EUO done!
# 2023-01-15 09:19:36,985 cisTopic     INFO     Reading ENCFF119IVK
# 2023-01-15 09:20:59,989 cisTopic     INFO     Computing barcode rank plot for ENCFF119IVK
# 2023-01-15 09:20:59,991 cisTopic     INFO     Counting fragments
# 2023-01-15 09:21:04,929 cisTopic     INFO     Marking barcodes with more than 100
# 2023-01-15 09:21:04,981 cisTopic     INFO     Returning plot data
# 2023-01-15 09:21:04,983 cisTopic     INFO     Returning valid barcodes
# 2023-01-15 09:21:09,956 cisTopic     INFO     Computing duplicate rate plot for ENCFF119IVK
# 2023-01-15 09:21:17,068 cisTopic     INFO     Return plot data
# 2023-01-15 09:21:17,248 cisTopic     INFO     Computing insert size distribution for ENCFF119IVK
# 2023-01-15 09:21:17,249 cisTopic     INFO     Counting fragments
# 2023-01-15 09:21:18,703 cisTopic     INFO     Returning plot data
# 2023-01-15 09:22:03,678 cisTopic     INFO     Computing TSS profile for ENCFF119IVK
# 2023-01-15 09:22:12,131 cisTopic     INFO     Formatting annnotation
# 2023-01-15 09:22:12,181 cisTopic     INFO     Creating coverage matrix
# 2023-01-15 09:22:37,775 cisTopic     INFO     Coverage matrix done
# 2023-01-15 09:22:44,568 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# 2023-01-15 09:22:49,660 cisTopic     INFO     Returning normalized sample TSS enrichment data
# 2023-01-15 09:22:49,848 cisTopic     INFO     Computing FRIP profile for ENCFF119IVK
# 2023-01-15 09:22:51,839 cisTopic     INFO     Counting fragments
# 2023-01-15 09:23:01,615 cisTopic     INFO     Intersecting fragments with regions
# 2023-01-15 09:23:40,594 cisTopic     INFO     Sample ENCFF119IVK done!
# 2023-01-15 09:23:40,595 cisTopic     INFO     Reading ENCFF683IBE
# 2023-01-15 09:25:19,235 cisTopic     INFO     Computing barcode rank plot for ENCFF683IBE
# 2023-01-15 09:25:19,238 cisTopic     INFO     Counting fragments
# 2023-01-15 09:25:26,746 cisTopic     INFO     Marking barcodes with more than 100
# 2023-01-15 09:25:26,801 cisTopic     INFO     Returning plot data
# 2023-01-15 09:25:26,803 cisTopic     INFO     Returning valid barcodes
# 2023-01-15 09:25:33,842 cisTopic     INFO     Computing duplicate rate plot for ENCFF683IBE
# 2023-01-15 09:25:43,222 cisTopic     INFO     Return plot data
# 2023-01-15 09:25:43,395 cisTopic     INFO     Computing insert size distribution for ENCFF683IBE
# 2023-01-15 09:25:43,396 cisTopic     INFO     Counting fragments
# 2023-01-15 09:25:45,320 cisTopic     INFO     Returning plot data
# 2023-01-15 09:26:41,466 cisTopic     INFO     Computing TSS profile for ENCFF683IBE
# 2023-01-15 09:26:51,919 cisTopic     INFO     Formatting annnotation
# 2023-01-15 09:26:51,966 cisTopic     INFO     Creating coverage matrix
# 2023-01-15 09:27:23,943 cisTopic     INFO     Coverage matrix done
# 2023-01-15 09:27:33,586 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# 2023-01-15 09:27:41,007 cisTopic     INFO     Returning normalized sample TSS enrichment data
# 2023-01-15 09:27:41,171 cisTopic     INFO     Computing FRIP profile for ENCFF683IBE
# 2023-01-15 09:27:43,106 cisTopic     INFO     Counting fragments
# 2023-01-15 09:27:55,072 cisTopic     INFO     Intersecting fragments with regions
# 2023-01-15 09:28:43,158 cisTopic     INFO     Sample ENCFF683IBE done!
# 2023-01-15 09:28:43,159 cisTopic     INFO     Reading ENCFF042ZJI
# 2023-01-15 09:30:16,005 cisTopic     INFO     Computing barcode rank plot for ENCFF042ZJI
# 2023-01-15 09:30:16,007 cisTopic     INFO     Counting fragments
# 2023-01-15 09:30:21,904 cisTopic     INFO     Marking barcodes with more than 100
# 2023-01-15 09:30:21,949 cisTopic     INFO     Returning plot data
# 2023-01-15 09:30:21,952 cisTopic     INFO     Returning valid barcodes
# 2023-01-15 09:30:27,870 cisTopic     INFO     Computing duplicate rate plot for ENCFF042ZJI
# 2023-01-15 09:30:35,614 cisTopic     INFO     Return plot data
# 2023-01-15 09:30:35,819 cisTopic     INFO     Computing insert size distribution for ENCFF042ZJI
# 2023-01-15 09:30:35,820 cisTopic     INFO     Counting fragments
# 2023-01-15 09:30:37,471 cisTopic     INFO     Returning plot data
# 2023-01-15 09:31:32,499 cisTopic     INFO     Computing TSS profile for ENCFF042ZJI
# 2023-01-15 09:31:41,788 cisTopic     INFO     Formatting annnotation
# 2023-01-15 09:31:41,838 cisTopic     INFO     Creating coverage matrix
# 2023-01-15 09:32:10,550 cisTopic     INFO     Coverage matrix done
# 2023-01-15 09:32:17,043 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# 2023-01-15 09:32:22,020 cisTopic     INFO     Returning normalized sample TSS enrichment data
# 2023-01-15 09:32:22,187 cisTopic     INFO     Computing FRIP profile for ENCFF042ZJI
# 2023-01-15 09:32:24,088 cisTopic     INFO     Counting fragments
# 2023-01-15 09:32:35,391 cisTopic     INFO     Intersecting fragments with regions
# 2023-01-15 09:33:19,562 cisTopic     INFO     Sample ENCFF042ZJI done!
# 2023-01-15 09:33:19,563 cisTopic     INFO     Reading ENCFF176LJV
# 2023-01-15 09:35:00,017 cisTopic     INFO     Computing barcode rank plot for ENCFF176LJV
# 2023-01-15 09:35:00,019 cisTopic     INFO     Counting fragments
# 2023-01-15 09:35:06,992 cisTopic     INFO     Marking barcodes with more than 100
# 2023-01-15 09:35:07,039 cisTopic     INFO     Returning plot data
# 2023-01-15 09:35:07,042 cisTopic     INFO     Returning valid barcodes
# 2023-01-15 09:35:14,203 cisTopic     INFO     Computing duplicate rate plot for ENCFF176LJV
# 2023-01-15 09:35:23,709 cisTopic     INFO     Return plot data
# 2023-01-15 09:35:23,921 cisTopic     INFO     Computing insert size distribution for ENCFF176LJV
# 2023-01-15 09:35:23,922 cisTopic     INFO     Counting fragments
# 2023-01-15 09:35:25,688 cisTopic     INFO     Returning plot data
# 2023-01-15 09:36:24,368 cisTopic     INFO     Computing TSS profile for ENCFF176LJV
# 2023-01-15 09:36:34,532 cisTopic     INFO     Formatting annnotation
# 2023-01-15 09:36:34,581 cisTopic     INFO     Creating coverage matrix
# 2023-01-15 09:37:06,852 cisTopic     INFO     Coverage matrix done
# 2023-01-15 09:37:15,342 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# 2023-01-15 09:37:21,946 cisTopic     INFO     Returning normalized sample TSS enrichment data
# 2023-01-15 09:37:22,113 cisTopic     INFO     Computing FRIP profile for ENCFF176LJV
# 2023-01-15 09:37:24,099 cisTopic     INFO     Counting fragments
# 2023-01-15 09:37:37,612 cisTopic     INFO     Intersecting fragments with regions
# 2023-01-15 09:38:26,477 cisTopic     INFO     Sample ENCFF176LJV done!
# 2023-01-15 09:38:26,478 cisTopic     INFO     Reading ENCFF101BLM
# 2023-01-15 09:39:56,674 cisTopic     INFO     Computing barcode rank plot for ENCFF101BLM
# 2023-01-15 09:39:56,676 cisTopic     INFO     Counting fragments
# 2023-01-15 09:40:02,766 cisTopic     INFO     Marking barcodes with more than 100
# 2023-01-15 09:40:02,819 cisTopic     INFO     Returning plot data
# 2023-01-15 09:40:02,821 cisTopic     INFO     Returning valid barcodes
# 2023-01-15 09:40:08,791 cisTopic     INFO     Computing duplicate rate plot for ENCFF101BLM
# 2023-01-15 09:40:16,714 cisTopic     INFO     Return plot data
# 2023-01-15 09:40:16,898 cisTopic     INFO     Computing insert size distribution for ENCFF101BLM
# 2023-01-15 09:40:16,899 cisTopic     INFO     Counting fragments
# 2023-01-15 09:40:18,473 cisTopic     INFO     Returning plot data
# 2023-01-15 09:41:10,246 cisTopic     INFO     Computing TSS profile for ENCFF101BLM
# 2023-01-15 09:41:19,734 cisTopic     INFO     Formatting annnotation
# 2023-01-15 09:41:19,782 cisTopic     INFO     Creating coverage matrix
# 2023-01-15 09:41:48,990 cisTopic     INFO     Coverage matrix done
# 2023-01-15 09:41:57,548 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# 2023-01-15 09:42:04,150 cisTopic     INFO     Returning normalized sample TSS enrichment data
# 2023-01-15 09:42:04,316 cisTopic     INFO     Computing FRIP profile for ENCFF101BLM
# 2023-01-15 09:42:06,259 cisTopic     INFO     Counting fragments
# 2023-01-15 09:42:17,425 cisTopic     INFO     Intersecting fragments with regions
# 2023-01-15 09:43:01,085 cisTopic     INFO     Sample ENCFF101BLM done!

# %% [markdown]
# We can plot a few QC plots and see how filtering would affect the cells called

# %%
from pycisTopic.qc import *

# Perform some filtering to keep only high quality cells
QC_filters = {
    'Log_unique_nr_frag': [2 , None],
    'FRIP':               [0.3, None],
    'TSS_enrichment':     [1   , None],
    'Dupl_rate':          [None, None]

}
bc_passing_filters = {}
for sample in fragments_dict:
    print("Sample", sample)
    FRIP_NR_FRAG_filter = plot_barcode_metrics(
        metadata_bc[sample],
        var_x='Log_unique_nr_frag',
        var_y='FRIP',
        min_x=QC_filters['Log_unique_nr_frag'][0],
        max_x=QC_filters['Log_unique_nr_frag'][1],
        min_y=QC_filters['FRIP'][0],
        max_y=QC_filters['FRIP'][1],
        return_cells=True,
        return_fig=False,
        plot=False
    )
    # Return figure to plot together with other metrics, and cells passing filters
    TSS_NR_FRAG_filter = plot_barcode_metrics(
        metadata_bc[sample],
        var_x='Log_unique_nr_frag',
        var_y='TSS_enrichment',
        min_x=QC_filters['Log_unique_nr_frag'][0],
        max_x=QC_filters['Log_unique_nr_frag'][1],
        min_y=QC_filters['TSS_enrichment'][0],
        max_y=QC_filters['TSS_enrichment'][1],
        return_cells=True,
        return_fig=False,
        plot=False
    )
    bc_passing_filters[sample] = list((set(FRIP_NR_FRAG_filter) & set(TSS_NR_FRAG_filter)))
# Out:
# Sample ENCFF187VMN
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# Sample ENCFF035SPT
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# Sample ENCFF622EUO
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# Sample ENCFF119IVK
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# Sample ENCFF683IBE
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# Sample ENCFF042ZJI
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# Sample ENCFF176LJV
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# Sample ENCFF101BLM
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(

# %%
# Dump and print the cells that passed!
pickle.dump(
    bc_passing_filters,
    open(os.path.join(work_dir, 'scATAC/quality_control/bc_passing_filters.pkl'), 'wb')
)
for sample in bc_passing_filters:
    print(f"{len(bc_passing_filters[sample])} barcodes passed QC stats for {sample}")
# Out:
# 3887 barcodes passed QC stats for ENCFF187VMN
# 5623 barcodes passed QC stats for ENCFF035SPT
# 5210 barcodes passed QC stats for ENCFF622EUO
# 4669 barcodes passed QC stats for ENCFF119IVK
# 6547 barcodes passed QC stats for ENCFF683IBE
# 4875 barcodes passed QC stats for ENCFF042ZJI
# 6208 barcodes passed QC stats for ENCFF176LJV
# 5236 barcodes passed QC stats for ENCFF101BLM

# %% [markdown]
# ## 4. pycisTopic analysis

# %% [markdown]
# We need to start by creating a pycisTopic object. A couple important things here
# - Use high quality barcodes from the previous step
# - If you have RNA used those matched barcodes too, this will help the downstream SCENIC+ analysis

# %%
# Grab the barcodes from the RNA to intersect with when creating cistopic objects
quality_rna_bcs = cell_data["barcode"].values

# %%
# Sequentially create cistopic objects
cistopic_objs = []
i = 0
for sample in fragments_dict:
    print("Sample", sample)
    cistopic_obj = create_cistopic_object_from_fragments(
        path_to_fragments=fragments_dict[sample],
        path_to_regions=path_to_regions[sample],
        path_to_blacklist=path_to_blacklist,
        metrics=metadata_bc[sample],
        valid_bc=list(set(bc_passing_filters[sample]) & set(quality_rna_bcs)),
        n_cpu=1,
        project=sample,
        split_pattern='-'
    )
    cistopic_objs.append(cistopic_obj)
    #i = i + 1
    #if i==2:
    #    break
# Out:
# Sample ENCFF187VMN
# 2023-01-15 13:35:41,783 cisTopic     INFO     Reading data for ENCFF187VMN
# 2023-01-15 13:37:13,912 cisTopic     INFO     metrics provided!
# 2023-01-15 13:37:20,379 cisTopic     INFO     valid_bc provided, selecting barcodes!
# 2023-01-15 13:37:25,970 cisTopic     INFO     Counting fragments in regions
# 2023-01-15 13:38:03,485 cisTopic     INFO     Creating fragment matrix
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/cistopic_class.py:881: PerformanceWarning: The following operation may generate 2170521468 cells in the resulting pandas object.
#   counts_df.groupby(["Name", "regionID"], sort=False, observed=True)
# 2023-01-15 13:38:55,024 cisTopic     INFO     Converting fragment matrix to sparse matrix
# 2023-01-15 13:39:07,204 cisTopic     INFO     Removing blacklisted regions
# 2023-01-15 13:39:10,609 cisTopic     INFO     Creating CistopicObject
# 2023-01-15 13:39:13,490 cisTopic     INFO     Done!
# Sample ENCFF035SPT
# 2023-01-15 13:39:14,312 cisTopic     INFO     Reading data for ENCFF035SPT
# 2023-01-15 13:40:48,559 cisTopic     INFO     metrics provided!
# 2023-01-15 13:40:55,590 cisTopic     INFO     valid_bc provided, selecting barcodes!
# 2023-01-15 13:41:01,626 cisTopic     INFO     Counting fragments in regions
# 2023-01-15 13:41:48,877 cisTopic     INFO     Creating fragment matrix
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/cistopic_class.py:881: PerformanceWarning: The following operation may generate 3125775900 cells in the resulting pandas object.
#   counts_df.groupby(["Name", "regionID"], sort=False, observed=True)
# 2023-01-15 13:42:53,922 cisTopic     INFO     Converting fragment matrix to sparse matrix
# 2023-01-15 13:43:11,570 cisTopic     INFO     Removing blacklisted regions
# 2023-01-15 13:43:15,172 cisTopic     INFO     Creating CistopicObject
# 2023-01-15 13:43:18,526 cisTopic     INFO     Done!
# Sample ENCFF622EUO
# 2023-01-15 13:43:19,252 cisTopic     INFO     Reading data for ENCFF622EUO
# 2023-01-15 13:45:04,902 cisTopic     INFO     metrics provided!
# 2023-01-15 13:45:11,648 cisTopic     INFO     valid_bc provided, selecting barcodes!
# 2023-01-15 13:45:17,569 cisTopic     INFO     Counting fragments in regions
# 2023-01-15 13:46:10,627 cisTopic     INFO     Creating fragment matrix
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/cistopic_class.py:881: PerformanceWarning: The following operation may generate 3088934289 cells in the resulting pandas object.
#   counts_df.groupby(["Name", "regionID"], sort=False, observed=True)
# 2023-01-15 13:47:26,153 cisTopic     INFO     Converting fragment matrix to sparse matrix
# 2023-01-15 13:47:43,174 cisTopic     INFO     Removing blacklisted regions
# 2023-01-15 13:47:46,588 cisTopic     INFO     Creating CistopicObject
# 2023-01-15 13:47:49,333 cisTopic     INFO     Done!
# Sample ENCFF119IVK
# 2023-01-15 13:47:50,056 cisTopic     INFO     Reading data for ENCFF119IVK
# 2023-01-15 13:49:07,215 cisTopic     INFO     metrics provided!
# 2023-01-15 13:49:12,185 cisTopic     INFO     valid_bc provided, selecting barcodes!
# 2023-01-15 13:49:16,417 cisTopic     INFO     Counting fragments in regions
# 2023-01-15 13:49:56,001 cisTopic     INFO     Creating fragment matrix
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/cistopic_class.py:881: PerformanceWarning: The following operation may generate 2732167172 cells in the resulting pandas object.
#   counts_df.groupby(["Name", "regionID"], sort=False, observed=True)
# 2023-01-15 13:50:55,080 cisTopic     INFO     Converting fragment matrix to sparse matrix
# 2023-01-15 13:51:10,142 cisTopic     INFO     Removing blacklisted regions
# 2023-01-15 13:51:13,569 cisTopic     INFO     Creating CistopicObject
# 2023-01-15 13:51:16,593 cisTopic     INFO     Done!
# Sample ENCFF683IBE
# 2023-01-15 13:51:17,372 cisTopic     INFO     Reading data for ENCFF683IBE
# 2023-01-15 13:53:03,707 cisTopic     INFO     metrics provided!
# 2023-01-15 13:53:12,496 cisTopic     INFO     valid_bc provided, selecting barcodes!
# 2023-01-15 13:53:19,273 cisTopic     INFO     Counting fragments in regions
# 2023-01-15 13:54:03,831 cisTopic     INFO     Creating fragment matrix
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/cistopic_class.py:881: PerformanceWarning: The following operation may generate 3619169480 cells in the resulting pandas object.
#   counts_df.groupby(["Name", "regionID"], sort=False, observed=True)
# 2023-01-15 13:55:11,892 cisTopic     INFO     Converting fragment matrix to sparse matrix
# 2023-01-15 13:55:31,379 cisTopic     INFO     Removing blacklisted regions
# 2023-01-15 13:55:34,831 cisTopic     INFO     Creating CistopicObject
# 2023-01-15 13:55:38,072 cisTopic     INFO     Done!
# Sample ENCFF042ZJI
# 2023-01-15 13:55:38,956 cisTopic     INFO     Reading data for ENCFF042ZJI
# 2023-01-15 13:57:10,913 cisTopic     INFO     metrics provided!
# 2023-01-15 13:57:16,736 cisTopic     INFO     valid_bc provided, selecting barcodes!
# 2023-01-15 13:57:21,728 cisTopic     INFO     Counting fragments in regions
# 2023-01-15 13:58:03,329 cisTopic     INFO     Creating fragment matrix
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/cistopic_class.py:881: PerformanceWarning: The following operation may generate 2688167984 cells in the resulting pandas object.
#   counts_df.groupby(["Name", "regionID"], sort=False, observed=True)
# 2023-01-15 13:58:58,984 cisTopic     INFO     Converting fragment matrix to sparse matrix
# 2023-01-15 13:59:13,585 cisTopic     INFO     Removing blacklisted regions
# 2023-01-15 13:59:16,949 cisTopic     INFO     Creating CistopicObject
# 2023-01-15 13:59:19,411 cisTopic     INFO     Done!
# Sample ENCFF176LJV
# 2023-01-15 13:59:20,099 cisTopic     INFO     Reading data for ENCFF176LJV
# 2023-01-15 14:00:58,640 cisTopic     INFO     metrics provided!
# 2023-01-15 14:01:05,215 cisTopic     INFO     valid_bc provided, selecting barcodes!
# 2023-01-15 14:01:10,819 cisTopic     INFO     Counting fragments in regions
# 2023-01-15 14:01:56,882 cisTopic     INFO     Creating fragment matrix
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/cistopic_class.py:881: PerformanceWarning: The following operation may generate 3498198340 cells in the resulting pandas object.
#   counts_df.groupby(["Name", "regionID"], sort=False, observed=True)
# 2023-01-15 14:03:01,780 cisTopic     INFO     Converting fragment matrix to sparse matrix
# 2023-01-15 14:03:20,489 cisTopic     INFO     Removing blacklisted regions
# 2023-01-15 14:03:23,842 cisTopic     INFO     Creating CistopicObject
# 2023-01-15 14:03:26,458 cisTopic     INFO     Done!
# Sample ENCFF101BLM
# 2023-01-15 14:03:27,180 cisTopic     INFO     Reading data for ENCFF101BLM
# 2023-01-15 14:04:57,056 cisTopic     INFO     metrics provided!
# 2023-01-15 14:05:02,777 cisTopic     INFO     valid_bc provided, selecting barcodes!
# 2023-01-15 14:05:07,354 cisTopic     INFO     Counting fragments in regions
# 2023-01-15 14:05:44,041 cisTopic     INFO     Creating fragment matrix
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/cistopic_class.py:881: PerformanceWarning: The following operation may generate 2886113232 cells in the resulting pandas object.
#   counts_df.groupby(["Name", "regionID"], sort=False, observed=True)
# 2023-01-15 14:06:40,662 cisTopic     INFO     Converting fragment matrix to sparse matrix
# 2023-01-15 14:06:56,343 cisTopic     INFO     Removing blacklisted regions
# 2023-01-15 14:06:59,760 cisTopic     INFO     Creating CistopicObject
# 2023-01-15 14:07:02,645 cisTopic     INFO     Done!

# %%
# Merge them
from pycisTopic.cistopic_class import merge
cistopic_obj = merge(cistopic_objs, project="mouse_adrenal", split_pattern="-")
# Out:
# 2023-01-15 14:07:12,189 cisTopic     INFO     cisTopic object 1 merged
# 2023-01-15 14:07:24,007 cisTopic     INFO     cisTopic object 2 merged
# 2023-01-15 14:07:37,736 cisTopic     INFO     cisTopic object 3 merged
# 2023-01-15 14:07:54,024 cisTopic     INFO     cisTopic object 4 merged
# 2023-01-15 14:08:12,074 cisTopic     INFO     cisTopic object 5 merged
# 2023-01-15 14:08:32,293 cisTopic     INFO     cisTopic object 6 merged
# 2023-01-15 14:08:54,490 cisTopic     INFO     cisTopic object 7 merged

# %%
# Add metadata
cistopic_obj.add_cell_data(cell_data.set_index("atac_bc_sample"), split_pattern="-")
# Out:
# Warning: Some cells in this CistopicObject are not present in this cell_data. Values will be filled with Nan
#
# Columns ['barcode', 'sample_id'] will be overwritten

# %%
# Save the cistopic object
pickle.dump(
    cistopic_obj,
    open(os.path.join(work_dir, 'scATAC/cistopic_obj.pkl'), 'wb')
)

# %% [markdown]
# Now that we have a pycisTopic object, we can fit some LDA models. Note this can take a long time if your number of iterations is high and you have a lot of cells and peaks. I recommend using the script `6_run_cistopic.py` for this step behind some kind of screen.

# %%
models = run_cgs_models(
    cistopic_obj,
    n_topics=[2,4,8],
    n_cpu=3,
    n_iter=100,
    random_state=555,
    alpha=50,
    alpha_by_topic=True,
    eta=0.1,
    eta_by_topic=False,
    save_path=None,
    _temp_dir = os.path.join(tmp_dir + 'ray_spill')
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 models = run_cgs_models(
#       2     cistopic_obj,
#       3     n_topics=[2,4,8],
#       4     n_cpu=3,
#       5     n_iter=100,
#       6     random_state=555,
#       7     alpha=50,
#       8     alpha_by_topic=True,
#       9     eta=0.1,
#      10     eta_by_topic=False,
#      11     save_path=None,
#      12     _temp_dir = os.path.join(tmp_dir + 'ray_spill')
#      13 )
#
# NameError: name 'run_cgs_models' is not defined

# %%
cistopic_obj.add_LDA_model(model)
pickle.dump(cistopic_obj,
            open(os.path.join(work_dir, 'scATAC/cistopic_obj.pkl'), 'wb'))

# %%
if not os.path.exists(os.path.join(work_dir, 'scATAC/models')):
    os.makedirs(os.path.join(work_dir, 'scATAC/models'))

pickle.dump(models,
            open(os.path.join(work_dir, 'scATAC/models/models_100_iter_LDA.pkl'), 'wb'))

# %% [markdown]
# Reload a previous iteration of the cistopic object and models if run separately

# %%
import pickle
cistopic_obj = pickle.load(open(os.path.join(work_dir, 'scATAC/cistopic_obj.pkl'), 'rb'))

# %%
models = pickle.load(open(os.path.join(work_dir, 'scATAC/models/models_50_iter_LDA.pkl'), 'rb'))

# %%
from pycisTopic.lda_models import *
model = evaluate_models(
    models,
    select_model=48,
    return_model=True,
    metrics=['Arun_2010','Cao_Juan_2009', 'Minmo_2011', 'loglikelihood'],
    plot_metrics=False
)

# %%
cistopic_obj.add_LDA_model(model)

# %%
cistopic_obj.selected_model.n_topic
# Out:
# 48

# %% [markdown]
# We can run dimensionality reduction to visualize our topic-cell matrix

# %%
from pycisTopic.clust_vis import *
run_umap(cistopic_obj, target  = 'cell', scale=True)
plot_metadata(cistopic_obj, reduction_name = 'UMAP', variables = ['celltype'])
# Out:
# 2023-01-30 09:21:10,248 cisTopic     INFO     Running UMAP

# %% [markdown]
# We can also see what topics are most enriched in each cell type via a UMAP and a heatmap

# %%
plot_topic(cistopic_obj, reduction_name = 'UMAP', num_columns = 4)

# %%
cell_topic_heatmap(cistopic_obj,
                     variables = ['celltype'],
                     scale = False,
                     legend_loc_x = 1.05,
                     legend_loc_y = -1.2,
                     legend_dist_y = -1,
                     figsize=(10,10),
                  )

# %%
pickle.dump(cistopic_obj,
            open(os.path.join(work_dir, 'scATAC/cistopic_obj_50_iter_model.pkl'), 'wb'))

# %% [markdown]
# Finally we can try to infer candidate enhancers via binarized topic regions or via differentially accessible regions analyis

# %%
import os
import pickle
cistopic_obj = pickle.load(open(os.path.join(work_dir, 'scATAC/cistopic_obj.pkl'), 'rb'))

# %%
from pycisTopic.topic_binarization import *
region_bin_topics_otsu = binarize_topics(cistopic_obj, method='otsu')
region_bin_topics_top3k = binarize_topics(cistopic_obj, method='ntop', ntop = 3000)

# %%
if not os.path.exists(os.path.join(work_dir, 'scATAC/candidate_enhancers')):
    os.makedirs(os.path.join(work_dir, 'scATAC/candidate_enhancers'))
import pickle
pickle.dump(region_bin_topics_otsu, open(os.path.join(work_dir, 'scATAC/candidate_enhancers/region_bin_topics_otsu.pkl'), 'wb'))
pickle.dump(region_bin_topics_top3k, open(os.path.join(work_dir, 'scATAC/candidate_enhancers/region_bin_topics_top3k.pkl'), 'wb'))

# %%
from pycisTopic.diff_features import *
imputed_acc_obj = impute_accessibility(cistopic_obj, selected_cells=None, selected_regions=None, scale_factor=10**6)
# Out:
# 2023-01-16 22:22:40,940 cisTopic     INFO     Imputing drop-outs
# 2023-01-16 22:23:57,019 cisTopic     INFO     Scaling
# 2023-01-16 22:25:12,129 cisTopic     INFO     Keep non zero rows
# 2023-01-16 22:26:43,179 cisTopic     INFO     Imputed accessibility sparsity: 0.6791389147778321
# 2023-01-16 22:26:43,181 cisTopic     INFO     Create CistopicImputedFeatures object
# 2023-01-16 22:26:43,182 cisTopic     INFO     Making matrix sparse

# %%
normalized_imputed_acc_obj = normalize_scores(imputed_acc_obj, scale_factor=10**4)
variable_regions = find_highly_variable_features(normalized_imputed_acc_obj, plot = False)

# %%
markers_dict = find_diff_features(cistopic_obj, imputed_acc_obj, variable='celltype', var_features=variable_regions, split_pattern = '-')
# Out:
# 2023-01-15 17:04:03,051 cisTopic     INFO     Imputing drop-outs
# 2023-01-15 17:05:09,028 cisTopic     INFO     Scaling
# 2023-01-15 17:06:24,540 cisTopic     INFO     Keep non zero rows
# 2023-01-15 17:07:55,954 cisTopic     INFO     Imputed accessibility sparsity: 0.6791389147778321
# 2023-01-15 17:07:55,956 cisTopic     INFO     Create CistopicImputedFeatures object
# 2023-01-15 17:07:55,957 cisTopic     INFO     Making matrix sparse

# %%
pickle.dump(markers_dict, open(os.path.join(work_dir, 'scATAC/candidate_enhancers/markers_dict.pkl'), 'wb'))

# %% [markdown]
# ## 5. pycisTarget analysis

# %% [markdown]
# We can now take our candidate enhacner regions from cisTopic modeling or from DARs and look for enriched motifs. The SCENIC universe uses pycisTarget to do this, which implements a couple different methods for motif enrichment. The default that are run are DEM and cisTarget

# %%
import pickle
region_bin_topics_otsu = pickle.load(open(os.path.join(work_dir, 'scATAC/candidate_enhancers/region_bin_topics_otsu.pkl'), 'rb'))
region_bin_topics_top3k = pickle.load(open(os.path.join(work_dir, 'scATAC/candidate_enhancers/region_bin_topics_top3k.pkl'), 'rb'))
markers_dict = pickle.load(open(os.path.join(work_dir, 'scATAC/candidate_enhancers/markers_dict.pkl'), 'rb'))

# %% [markdown]
# Convert things into pyranges format

# %%
import pyranges as pr
from pycistarget.utils import region_names_to_coordinates
region_sets = {}
region_sets['topics_otsu'] = {}
region_sets['topics_top_3'] = {}
region_sets['DARs'] = {}
for topic in region_bin_topics_otsu.keys():
    regions = region_bin_topics_otsu[topic].index[region_bin_topics_otsu[topic].index.str.startswith('chr')] #only keep regions on known chromosomes
    region_sets['topics_otsu'][topic] = pr.PyRanges(region_names_to_coordinates(regions))
for topic in region_bin_topics_top3k.keys():
    regions = region_bin_topics_top3k[topic].index[region_bin_topics_top3k[topic].index.str.startswith('chr')] #only keep regions on known chromosomes
    region_sets['topics_top_3'][topic] = pr.PyRanges(region_names_to_coordinates(regions))
for DAR in markers_dict.keys():
    regions = markers_dict[DAR].index[markers_dict[DAR].index.str.startswith('chr')] #only keep regions on known chromosomes
    if len(regions) > 0:
        region_sets['DARs'][DAR] = pr.PyRanges(region_names_to_coordinates(regions))

# %%
for key in region_sets.keys():
    print(f'{key}: {region_sets[key].keys()}')
# Out:
# topics_otsu: dict_keys(['Topic1', 'Topic2', 'Topic3', 'Topic4', 'Topic5', 'Topic6', 'Topic7', 'Topic8', 'Topic9', 'Topic10', 'Topic11', 'Topic12', 'Topic13', 'Topic14', 'Topic15', 'Topic16', 'Topic17', 'Topic18', 'Topic19', 'Topic20', 'Topic21', 'Topic22', 'Topic23', 'Topic24', 'Topic25', 'Topic26', 'Topic27', 'Topic28', 'Topic29', 'Topic30', 'Topic31', 'Topic32', 'Topic33', 'Topic34', 'Topic35', 'Topic36', 'Topic37', 'Topic38', 'Topic39', 'Topic40', 'Topic41', 'Topic42', 'Topic43', 'Topic44', 'Topic45', 'Topic46', 'Topic47', 'Topic48'])
# topics_top_3: dict_keys(['Topic1', 'Topic2', 'Topic3', 'Topic4', 'Topic5', 'Topic6', 'Topic7', 'Topic8', 'Topic9', 'Topic10', 'Topic11', 'Topic12', 'Topic13', 'Topic14', 'Topic15', 'Topic16', 'Topic17', 'Topic18', 'Topic19', 'Topic20', 'Topic21', 'Topic22', 'Topic23', 'Topic24', 'Topic25', 'Topic26', 'Topic27', 'Topic28', 'Topic29', 'Topic30', 'Topic31', 'Topic32', 'Topic33', 'Topic34', 'Topic35', 'Topic36', 'Topic37', 'Topic38', 'Topic39', 'Topic40', 'Topic41', 'Topic42', 'Topic43', 'Topic44', 'Topic45', 'Topic46', 'Topic47', 'Topic48'])
# DARs: dict_keys(['Adipocytes', 'Capsule', 'Cortex', 'Endothelial', 'Fibroblast', 'Hepatocyte', 'Macrophages', 'Medulla', 'Smooth_muscle', 'Sox10+', 'Stromal'])

# %% [markdown]
# We need to point to our locally downloaded cisTarget databases. For SCENIC+, we need a ranking database, a scores database and a motifs-to-tf annotation table. We will utilize the ENCODE SCREEN regions scoring database here

# %%
db_fpath = "/cellar/users/aklie/opt/shared/SCENIC+/databases"
motif_annot_fpath = "/cellar/users/aklie/opt/shared/SCENIC+/motif_annotation"

# %%
rankings_db = os.path.join(db_fpath, 'mm10_screen_v10_clust.regions_vs_motifs.rankings.feather')
scores_db =  os.path.join(db_fpath, 'mm10_screen_v10_clust.regions_vs_motifs.scores.feather')
motif_annotation = os.path.join(motif_annot_fpath, 'motifs-v10nr_clust-nr.mgi-m0.001-o0.0.tbl')

# %%
if not os.path.exists(os.path.join(work_dir, 'motifs')):
    os.makedirs(os.path.join(work_dir, 'motifs'))

# %%
from scenicplus.wrappers.run_pycistarget import run_pycistarget
run_pycistarget(
    region_sets = region_sets,
    species = 'mus_musculus',
    save_path = os.path.join(work_dir, 'motifs'),
    ctx_db_path = rankings_db,
    dem_db_path = scores_db,
    path_to_motif_annotations = motif_annotation,
    run_without_promoters = True,
    n_cpu = 8,
    _temp_dir = os.path.join(tmp_dir, 'ray_spill'),
    annotation_version = 'v10nr_clust',
    )
# Out:
# 2023-01-05 13:57:14,357 pycisTarget_wrapper INFO     pbmc_tutorial/motifs folder already exists.
# 2023-01-05 13:57:15,330 pycisTarget_wrapper INFO     Loading cisTarget database for topics_otsu
# 2023-01-05 13:57:15,331 cisTarget    INFO     Reading cisTarget database
# 2023-01-05 13:59:30,684 pycisTarget_wrapper INFO     Running cisTarget for topics_otsu
# 2023-01-05 13:59:44,222	INFO worker.py:1519 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (ctx_internal_ray pid=457406) 2023-01-05 13:59:55,541 cisTarget    INFO     Running cisTarget for Topic1 which has 8612 regions
# (ctx_internal_ray pid=457408) 2023-01-05 13:59:55,754 cisTarget    INFO     Running cisTarget for Topic2 which has 6836 regions
# (ctx_internal_ray pid=457410) 2023-01-05 13:59:56,130 cisTarget    INFO     Running cisTarget for Topic3 which has 5749 regions
# (ctx_internal_ray pid=457413) 2023-01-05 13:59:56,690 cisTarget    INFO     Running cisTarget for Topic4 which has 4978 regions
# (ctx_internal_ray pid=457405) 2023-01-05 13:59:57,023 cisTarget    INFO     Running cisTarget for Topic5 which has 3035 regions
# (ctx_internal_ray pid=457409) 2023-01-05 13:59:57,512 cisTarget    INFO     Running cisTarget for Topic6 which has 4166 regions
# (ctx_internal_ray pid=457411) 2023-01-05 13:59:58,262 cisTarget    INFO     Running cisTarget for Topic7 which has 7335 regions
# (ctx_internal_ray pid=457407) 2023-01-05 13:59:58,606 cisTarget    INFO     Running cisTarget for Topic8 which has 8164 regions
# (ctx_internal_ray pid=457408) 2023-01-05 14:00:43,772 cisTarget    INFO     Annotating motifs for Topic2
# (ctx_internal_ray pid=457405) 2023-01-05 14:00:44,097 cisTarget    INFO     Annotating motifs for Topic5
# (ctx_internal_ray pid=457413) 2023-01-05 14:00:44,310 cisTarget    INFO     Annotating motifs for Topic4
# (ctx_internal_ray pid=457409) 2023-01-05 14:00:45,075 cisTarget    INFO     Annotating motifs for Topic6
# (ctx_internal_ray pid=457406) 2023-01-05 14:00:46,075 cisTarget    INFO     Annotating motifs for Topic1
# (ctx_internal_ray pid=457410) 2023-01-05 14:00:46,347 cisTarget    INFO     Annotating motifs for Topic3
# (ctx_internal_ray pid=457408) 2023-01-05 14:00:47,380 cisTarget    INFO     Getting cistromes for Topic2
# (ctx_internal_ray pid=457405) 2023-01-05 14:00:47,466 cisTarget    INFO     Getting cistromes for Topic5
# (ctx_internal_ray pid=457411) 2023-01-05 14:00:47,982 cisTarget    INFO     Annotating motifs for Topic7
# (ctx_internal_ray pid=457413) 2023-01-05 14:00:48,162 cisTarget    INFO     Getting cistromes for Topic4
# (ctx_internal_ray pid=457408) 2023-01-05 14:00:48,628 cisTarget    INFO     Running cisTarget for Topic9 which has 7296 regions
# (ctx_internal_ray pid=457405) 2023-01-05 14:00:48,729 cisTarget    INFO     Running cisTarget for Topic10 which has 5166 regions
# (ctx_internal_ray pid=457407) 2023-01-05 14:00:48,859 cisTarget    INFO     Annotating motifs for Topic8
# (ctx_internal_ray pid=457409) 2023-01-05 14:00:49,033 cisTarget    INFO     Getting cistromes for Topic6
# (ctx_internal_ray pid=457413) 2023-01-05 14:00:49,727 cisTarget    INFO     Running cisTarget for Topic11 which has 3849 regions
# (ctx_internal_ray pid=457406) 2023-01-05 14:00:50,548 cisTarget    INFO     Getting cistromes for Topic1
# (ctx_internal_ray pid=457409) 2023-01-05 14:00:50,623 cisTarget    INFO     Running cisTarget for Topic12 which has 4197 regions
# (ctx_internal_ray pid=457410) 2023-01-05 14:00:51,024 cisTarget    INFO     Getting cistromes for Topic3
# (ctx_internal_ray pid=457411) 2023-01-05 14:00:52,255 cisTarget    INFO     Getting cistromes for Topic7
# (ctx_internal_ray pid=457406) 2023-01-05 14:00:53,069 cisTarget    INFO     Running cisTarget for Topic13 which has 1636 regions
# (ctx_internal_ray pid=457410) 2023-01-05 14:00:53,114 cisTarget    INFO     Running cisTarget for Topic14 which has 7267 regions
# (ctx_internal_ray pid=457407) 2023-01-05 14:00:53,448 cisTarget    INFO     Getting cistromes for Topic8
# (ctx_internal_ray pid=457411) 2023-01-05 14:00:54,929 cisTarget    INFO     Running cisTarget for Topic15 which has 2501 regions
# (ctx_internal_ray pid=457407) 2023-01-05 14:00:56,268 cisTarget    INFO     Running cisTarget for Topic16 which has 3718 regions
# (ctx_internal_ray pid=457413) 2023-01-05 14:01:31,143 cisTarget    INFO     Annotating motifs for Topic11
# (ctx_internal_ray pid=457405) 2023-01-05 14:01:32,161 cisTarget    INFO     Annotating motifs for Topic10
# (ctx_internal_ray pid=457408) 2023-01-05 14:01:33,123 cisTarget    INFO     Annotating motifs for Topic9
# (ctx_internal_ray pid=457409) 2023-01-05 14:01:33,161 cisTarget    INFO     Annotating motifs for Topic12
# (ctx_internal_ray pid=457406) 2023-01-05 14:01:33,621 cisTarget    INFO     Annotating motifs for Topic13
# (ctx_internal_ray pid=457413) 2023-01-05 14:01:34,833 cisTarget    INFO     Getting cistromes for Topic11
# (ctx_internal_ray pid=457410) 2023-01-05 14:01:35,207 cisTarget    INFO     Annotating motifs for Topic14
# (ctx_internal_ray pid=457411) 2023-01-05 14:01:35,442 cisTarget    INFO     Annotating motifs for Topic15
# (ctx_internal_ray pid=457405) 2023-01-05 14:01:36,771 cisTarget    INFO     Getting cistromes for Topic10
# (ctx_internal_ray pid=457406) 2023-01-05 14:01:36,949 cisTarget    INFO     Getting cistromes for Topic13
# (ctx_internal_ray pid=457409) 2023-01-05 14:01:37,357 cisTarget    INFO     Getting cistromes for Topic12
# (ctx_internal_ray pid=457407) 2023-01-05 14:01:37,759 cisTarget    INFO     Annotating motifs for Topic16
# (ctx_internal_ray pid=457408) 2023-01-05 14:01:37,926 cisTarget    INFO     Getting cistromes for Topic9
# (ctx_internal_ray pid=457411) 2023-01-05 14:01:38,760 cisTarget    INFO     Getting cistromes for Topic15
# (ctx_internal_ray pid=457410) 2023-01-05 14:01:39,207 cisTarget    INFO     Getting cistromes for Topic14
# (ctx_internal_ray pid=457407) 2023-01-05 14:01:41,809 cisTarget    INFO     Getting cistromes for Topic16
# 2023-01-05 14:01:51,167 cisTarget    INFO     Done!
# 2023-01-05 14:01:51,170 pycisTarget_wrapper INFO     Created folder : pbmc_tutorial/motifs/CTX_topics_otsu_All
# 2023-01-05 14:01:51,481 pycisTarget_wrapper INFO     Running cisTarget without promoters for topics_otsu
# 2023-01-05 14:02:18,312	INFO worker.py:1519 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (ctx_internal_ray pid=458936) 2023-01-05 14:02:29,913 cisTarget    INFO     Running cisTarget for Topic1 which has 7108 regions
# (ctx_internal_ray pid=458933) 2023-01-05 14:02:30,091 cisTarget    INFO     Running cisTarget for Topic2 which has 5239 regions
# (ctx_internal_ray pid=458937) 2023-01-05 14:02:30,441 cisTarget    INFO     Running cisTarget for Topic3 which has 4512 regions
# (ctx_internal_ray pid=458934) 2023-01-05 14:02:30,771 cisTarget    INFO     Running cisTarget for Topic4 which has 3691 regions
# (ctx_internal_ray pid=458939) 2023-01-05 14:02:31,153 cisTarget    INFO     Running cisTarget for Topic5 which has 2423 regions
# (ctx_internal_ray pid=458938) 2023-01-05 14:02:31,733 cisTarget    INFO     Running cisTarget for Topic6 which has 2975 regions
# (ctx_internal_ray pid=458940) 2023-01-05 14:02:32,242 cisTarget    INFO     Running cisTarget for Topic7 which has 5911 regions
# (ctx_internal_ray pid=458935) 2023-01-05 14:02:32,648 cisTarget    INFO     Running cisTarget for Topic8 which has 6352 regions
# (ctx_internal_ray pid=458933) 2023-01-05 14:03:15,418 cisTarget    INFO     Annotating motifs for Topic2
# (ctx_internal_ray pid=458939) 2023-01-05 14:03:17,743 cisTarget    INFO     Annotating motifs for Topic5
# (ctx_internal_ray pid=458933) 2023-01-05 14:03:18,546 cisTarget    INFO     Getting cistromes for Topic2
# (ctx_internal_ray pid=458934) 2023-01-05 14:03:18,713 cisTarget    INFO     Annotating motifs for Topic4
# (ctx_internal_ray pid=458938) 2023-01-05 14:03:19,121 cisTarget    INFO     Annotating motifs for Topic6
# (ctx_internal_ray pid=458933) 2023-01-05 14:03:19,309 cisTarget    INFO     Running cisTarget for Topic9 which has 5446 regions
# (ctx_internal_ray pid=458937) 2023-01-05 14:03:19,261 cisTarget    INFO     Annotating motifs for Topic3
# (ctx_internal_ray pid=458936) 2023-01-05 14:03:20,032 cisTarget    INFO     Annotating motifs for Topic1
# (ctx_internal_ray pid=458939) 2023-01-05 14:03:21,202 cisTarget    INFO     Getting cistromes for Topic5
# (ctx_internal_ray pid=458940) 2023-01-05 14:03:21,179 cisTarget    INFO     Annotating motifs for Topic7
# (ctx_internal_ray pid=458939) 2023-01-05 14:03:21,968 cisTarget    INFO     Running cisTarget for Topic10 which has 504 regions
# (ctx_internal_ray pid=458934) 2023-01-05 14:03:23,005 cisTarget    INFO     Getting cistromes for Topic4
# (ctx_internal_ray pid=458935) 2023-01-05 14:03:23,112 cisTarget    INFO     Annotating motifs for Topic8
# (ctx_internal_ray pid=458938) 2023-01-05 14:03:23,189 cisTarget    INFO     Getting cistromes for Topic6
# (ctx_internal_ray pid=458937) 2023-01-05 14:03:23,276 cisTarget    INFO     Getting cistromes for Topic3
# (ctx_internal_ray pid=458936) 2023-01-05 14:03:24,484 cisTarget    INFO     Getting cistromes for Topic1
# (ctx_internal_ray pid=458934) 2023-01-05 14:03:24,492 cisTarget    INFO     Running cisTarget for Topic11 which has 2288 regions
# (ctx_internal_ray pid=458938) 2023-01-05 14:03:24,562 cisTarget    INFO     Running cisTarget for Topic12 which has 2132 regions
# (ctx_internal_ray pid=458937) 2023-01-05 14:03:24,672 cisTarget    INFO     Running cisTarget for Topic13 which has 358 regions
# (ctx_internal_ray pid=458940) 2023-01-05 14:03:25,652 cisTarget    INFO     Getting cistromes for Topic7
# (ctx_internal_ray pid=458936) 2023-01-05 14:03:27,023 cisTarget    INFO     Running cisTarget for Topic14 which has 5451 regions
# (ctx_internal_ray pid=458935) 2023-01-05 14:03:27,516 cisTarget    INFO     Getting cistromes for Topic8
# (ctx_internal_ray pid=458940) 2023-01-05 14:03:27,961 cisTarget    INFO     Running cisTarget for Topic15 which has 1111 regions
# (ctx_internal_ray pid=458935) 2023-01-05 14:03:30,026 cisTarget    INFO     Running cisTarget for Topic16 which has 465 regions
# (ctx_internal_ray pid=458939) 2023-01-05 14:04:02,242 cisTarget    INFO     Annotating motifs for Topic10
# (ctx_internal_ray pid=458933) 2023-01-05 14:04:03,102 cisTarget    INFO     Annotating motifs for Topic9
# (ctx_internal_ray pid=458938) 2023-01-05 14:04:04,151 cisTarget    INFO     Annotating motifs for Topic12
# (ctx_internal_ray pid=458937) 2023-01-05 14:04:04,662 cisTarget    INFO     Annotating motifs for Topic13
# (ctx_internal_ray pid=458934) 2023-01-05 14:04:05,561 cisTarget    INFO     Annotating motifs for Topic11
# (ctx_internal_ray pid=458939) 2023-01-05 14:04:05,666 cisTarget    INFO     Getting cistromes for Topic10
# (ctx_internal_ray pid=458940) 2023-01-05 14:04:07,041 cisTarget    INFO     Annotating motifs for Topic15
# (ctx_internal_ray pid=458936) 2023-01-05 14:04:07,184 cisTarget    INFO     Annotating motifs for Topic14
# (ctx_internal_ray pid=458938) 2023-01-05 14:04:07,355 cisTarget    INFO     Getting cistromes for Topic12
# (ctx_internal_ray pid=458933) 2023-01-05 14:04:07,403 cisTarget    INFO     Getting cistromes for Topic9
# (ctx_internal_ray pid=458937) 2023-01-05 14:04:07,649 cisTarget    INFO     Getting cistromes for Topic13
# (ctx_internal_ray pid=458934) 2023-01-05 14:04:08,890 cisTarget    INFO     Getting cistromes for Topic11
# (ctx_internal_ray pid=458935) 2023-01-05 14:04:09,400 cisTarget    INFO     Annotating motifs for Topic16
# (ctx_internal_ray pid=458940) 2023-01-05 14:04:09,979 cisTarget    INFO     Getting cistromes for Topic15
# (ctx_internal_ray pid=458936) 2023-01-05 14:04:10,636 cisTarget    INFO     Getting cistromes for Topic14
# (ctx_internal_ray pid=458935) 2023-01-05 14:04:12,313 cisTarget    INFO     Getting cistromes for Topic16
# 2023-01-05 14:04:17,874 cisTarget    INFO     Done!
# 2023-01-05 14:04:17,877 pycisTarget_wrapper INFO     Created folder:pbmc_tutorial/motifs/CTX_topics_otsu_No_promoters
# 2023-01-05 14:04:18,172 pycisTarget_wrapper INFO     Running DEM for topics_otsu
# 2023-01-05 14:04:18,173 DEM          INFO     Reading DEM database
# 2023-01-05 14:06:29,006 DEM          INFO     Creating contrast groups
# 2023-01-05 14:07:03,361	INFO worker.py:1519 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (DEM_internal_ray pid=460453) 2023-01-05 14:07:18,356 DEM          INFO     Computing DEM for Topic5
# (DEM_internal_ray pid=460452) 2023-01-05 14:07:18,653 DEM          INFO     Computing DEM for Topic3
# (DEM_internal_ray pid=460456) 2023-01-05 14:07:18,677 DEM          INFO     Computing DEM for Topic4
# (DEM_internal_ray pid=460457) 2023-01-05 14:07:18,893 DEM          INFO     Computing DEM for Topic2
# (DEM_internal_ray pid=460454) 2023-01-05 14:07:19,072 DEM          INFO     Computing DEM for Topic6
# (DEM_internal_ray pid=460458) 2023-01-05 14:07:19,532 DEM          INFO     Computing DEM for Topic1
# (DEM_internal_ray pid=460451) 2023-01-05 14:07:20,770 DEM          INFO     Computing DEM for Topic7
# (DEM_internal_ray pid=460455) 2023-01-05 14:07:21,704 DEM          INFO     Computing DEM for Topic8
# (DEM_internal_ray pid=460453) 2023-01-05 14:07:29,754 DEM          INFO     Computing DEM for Topic9
# (DEM_internal_ray pid=460457) 2023-01-05 14:07:31,194 DEM          INFO     Computing DEM for Topic11
# (DEM_internal_ray pid=460454) 2023-01-05 14:07:31,129 DEM          INFO     Computing DEM for Topic10
# (DEM_internal_ray pid=460452) 2023-01-05 14:07:33,103 DEM          INFO     Computing DEM for Topic13
# (DEM_internal_ray pid=460456) 2023-01-05 14:07:33,501 DEM          INFO     Computing DEM for Topic12
# (DEM_internal_ray pid=460455) 2023-01-05 14:07:40,844 DEM          INFO     Computing DEM for Topic14
# (DEM_internal_ray pid=460451) 2023-01-05 14:07:44,118 DEM          INFO     Computing DEM for Topic15
# (DEM_internal_ray pid=460457) 2023-01-05 14:07:46,137 DEM          INFO     Computing DEM for Topic16
# 2023-01-05 14:08:50,344 DEM          INFO     Forming cistromes
# 2023-01-05 14:08:59,692 DEM          INFO     Done!
# 2023-01-05 14:09:03,872 pycisTarget_wrapper INFO     Created folder : pbmc_tutorial/motifs/DEM_topics_otsu_All
# 2023-01-05 14:09:04,283 pycisTarget_wrapper INFO     Running DEM without promoters for topics_otsu
# 2023-01-05 14:09:18,850 DEM          INFO     Creating contrast groups
# 2023-01-05 14:09:33,430	INFO worker.py:1519 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (DEM_internal_ray pid=461807) 2023-01-05 14:09:50,344 DEM          INFO     Computing DEM for Topic2
# (DEM_internal_ray pid=461811) 2023-01-05 14:09:50,697 DEM          INFO     Computing DEM for Topic3
# (DEM_internal_ray pid=461804) 2023-01-05 14:09:50,786 DEM          INFO     Computing DEM for Topic5
# (DEM_internal_ray pid=461810) 2023-01-05 14:09:50,881 DEM          INFO     Computing DEM for Topic4
# (DEM_internal_ray pid=461805) 2023-01-05 14:09:50,970 DEM          INFO     Computing DEM for Topic1
# (DEM_internal_ray pid=461803) 2023-01-05 14:09:51,405 DEM          INFO     Computing DEM for Topic6
# (DEM_internal_ray pid=461806) 2023-01-05 14:09:53,055 DEM          INFO     Computing DEM for Topic7
# (DEM_internal_ray pid=461808) 2023-01-05 14:09:53,298 DEM          INFO     Computing DEM for Topic8
# (DEM_internal_ray pid=461803) 2023-01-05 14:10:01,605 DEM          INFO     Computing DEM for Topic10
# (DEM_internal_ray pid=461807) 2023-01-05 14:10:01,980 DEM          INFO     Computing DEM for Topic9
# (DEM_internal_ray pid=461804) 2023-01-05 14:10:02,228 DEM          INFO     Computing DEM for Topic11
# (DEM_internal_ray pid=461808) 2023-01-05 14:10:04,504 DEM          INFO     Computing DEM for Topic12
# (DEM_internal_ray pid=461811) 2023-01-05 14:10:06,397 DEM          INFO     Computing DEM for Topic13
# (DEM_internal_ray pid=461810) 2023-01-05 14:10:08,256 DEM          INFO     Computing DEM for Topic14
# (DEM_internal_ray pid=461811) 2023-01-05 14:10:19,190 DEM          INFO     Computing DEM for Topic16
# (DEM_internal_ray pid=461803) 2023-01-05 14:10:19,363 DEM          INFO     Computing DEM for Topic15
# 2023-01-05 14:10:41,460 DEM          INFO     Forming cistromes
# 2023-01-05 14:10:53,414 DEM          INFO     Done!
# 2023-01-05 14:10:57,236 pycisTarget_wrapper INFO     Created folder : pbmc_tutorial/motifs/DEM_topics_otsu_No_promoters
# 2023-01-05 14:10:57,707 pycisTarget_wrapper INFO     Loading cisTarget database for topics_top_3
# 2023-01-05 14:10:57,709 cisTarget    INFO     Reading cisTarget database
# 2023-01-05 14:13:10,398 pycisTarget_wrapper INFO     Running cisTarget for topics_top_3
# 2023-01-05 14:13:23,289	INFO worker.py:1519 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (ctx_internal_ray pid=463284) 2023-01-05 14:13:34,364 cisTarget    INFO     Running cisTarget for Topic1 which has 3407 regions
# (ctx_internal_ray pid=463281) 2023-01-05 14:13:34,619 cisTarget    INFO     Running cisTarget for Topic2 which has 3295 regions
# (ctx_internal_ray pid=463283) 2023-01-05 14:13:34,594 cisTarget    INFO     Running cisTarget for Topic3 which has 3345 regions
# (ctx_internal_ray pid=463280) 2023-01-05 14:13:35,204 cisTarget    INFO     Running cisTarget for Topic4 which has 3438 regions
# (ctx_internal_ray pid=463282) 2023-01-05 14:13:35,337 cisTarget    INFO     Running cisTarget for Topic5 which has 3416 regions
# (ctx_internal_ray pid=463285) 2023-01-05 14:13:35,647 cisTarget    INFO     Running cisTarget for Topic6 which has 3535 regions
# (ctx_internal_ray pid=463286) 2023-01-05 14:13:36,018 cisTarget    INFO     Running cisTarget for Topic7 which has 3277 regions
# (ctx_internal_ray pid=463287) 2023-01-05 14:13:36,326 cisTarget    INFO     Running cisTarget for Topic8 which has 3419 regions
# (ctx_internal_ray pid=463281) 2023-01-05 14:14:20,438 cisTarget    INFO     Annotating motifs for Topic2
# (ctx_internal_ray pid=463284) 2023-01-05 14:14:21,282 cisTarget    INFO     Annotating motifs for Topic1
# (ctx_internal_ray pid=463280) 2023-01-05 14:14:22,398 cisTarget    INFO     Annotating motifs for Topic4
# (ctx_internal_ray pid=463282) 2023-01-05 14:14:22,690 cisTarget    INFO     Annotating motifs for Topic5
# (ctx_internal_ray pid=463283) 2023-01-05 14:14:23,069 cisTarget    INFO     Annotating motifs for Topic3
# (ctx_internal_ray pid=463286) 2023-01-05 14:14:23,142 cisTarget    INFO     Annotating motifs for Topic7
# (ctx_internal_ray pid=463287) 2023-01-05 14:14:23,362 cisTarget    INFO     Annotating motifs for Topic8
# (ctx_internal_ray pid=463285) 2023-01-05 14:14:23,534 cisTarget    INFO     Annotating motifs for Topic6
# (ctx_internal_ray pid=463281) 2023-01-05 14:14:23,716 cisTarget    INFO     Getting cistromes for Topic2
# (ctx_internal_ray pid=463281) 2023-01-05 14:14:24,515 cisTarget    INFO     Running cisTarget for Topic9 which has 3251 regions
# (ctx_internal_ray pid=463284) 2023-01-05 14:14:24,920 cisTarget    INFO     Getting cistromes for Topic1
# (ctx_internal_ray pid=463280) 2023-01-05 14:14:25,876 cisTarget    INFO     Getting cistromes for Topic4
# (ctx_internal_ray pid=463282) 2023-01-05 14:14:26,156 cisTarget    INFO     Getting cistromes for Topic5
# (ctx_internal_ray pid=463284) 2023-01-05 14:14:26,154 cisTarget    INFO     Running cisTarget for Topic10 which has 3863 regions
# (ctx_internal_ray pid=463283) 2023-01-05 14:14:26,816 cisTarget    INFO     Getting cistromes for Topic3
# (ctx_internal_ray pid=463286) 2023-01-05 14:14:26,699 cisTarget    INFO     Getting cistromes for Topic7
# (ctx_internal_ray pid=463285) 2023-01-05 14:14:26,936 cisTarget    INFO     Getting cistromes for Topic6
# (ctx_internal_ray pid=463280) 2023-01-05 14:14:27,052 cisTarget    INFO     Running cisTarget for Topic11 which has 3587 regions
# (ctx_internal_ray pid=463282) 2023-01-05 14:14:27,220 cisTarget    INFO     Running cisTarget for Topic12 which has 3950 regions
# (ctx_internal_ray pid=463287) 2023-01-05 14:14:27,239 cisTarget    INFO     Getting cistromes for Topic8
# (ctx_internal_ray pid=463283) 2023-01-05 14:14:28,218 cisTarget    INFO     Running cisTarget for Topic13 which has 4129 regions
# (ctx_internal_ray pid=463286) 2023-01-05 14:14:28,238 cisTarget    INFO     Running cisTarget for Topic14 which has 3429 regions
# (ctx_internal_ray pid=463285) 2023-01-05 14:14:28,431 cisTarget    INFO     Running cisTarget for Topic15 which has 3798 regions
# (ctx_internal_ray pid=463287) 2023-01-05 14:14:28,668 cisTarget    INFO     Running cisTarget for Topic16 which has 3974 regions
# (ctx_internal_ray pid=463281) 2023-01-05 14:15:07,674 cisTarget    INFO     Annotating motifs for Topic9
# (ctx_internal_ray pid=463284) 2023-01-05 14:15:07,951 cisTarget    INFO     Annotating motifs for Topic10
# (ctx_internal_ray pid=463280) 2023-01-05 14:15:08,464 cisTarget    INFO     Annotating motifs for Topic11
# (ctx_internal_ray pid=463286) 2023-01-05 14:15:09,081 cisTarget    INFO     Annotating motifs for Topic14
# (ctx_internal_ray pid=463282) 2023-01-05 14:15:09,442 cisTarget    INFO     Annotating motifs for Topic12
# (ctx_internal_ray pid=463285) 2023-01-05 14:15:10,427 cisTarget    INFO     Annotating motifs for Topic15
# (ctx_internal_ray pid=463287) 2023-01-05 14:15:10,611 cisTarget    INFO     Annotating motifs for Topic16
# (ctx_internal_ray pid=463283) 2023-01-05 14:15:11,134 cisTarget    INFO     Annotating motifs for Topic13
# (ctx_internal_ray pid=463281) 2023-01-05 14:15:11,388 cisTarget    INFO     Getting cistromes for Topic9
# (ctx_internal_ray pid=463284) 2023-01-05 14:15:12,065 cisTarget    INFO     Getting cistromes for Topic10
# (ctx_internal_ray pid=463280) 2023-01-05 14:15:12,074 cisTarget    INFO     Getting cistromes for Topic11
# (ctx_internal_ray pid=463286) 2023-01-05 14:15:12,566 cisTarget    INFO     Getting cistromes for Topic14
# (ctx_internal_ray pid=463282) 2023-01-05 14:15:13,345 cisTarget    INFO     Getting cistromes for Topic12
# (ctx_internal_ray pid=463285) 2023-01-05 14:15:14,030 cisTarget    INFO     Getting cistromes for Topic15
# (ctx_internal_ray pid=463287) 2023-01-05 14:15:14,778 cisTarget    INFO     Getting cistromes for Topic16
# (ctx_internal_ray pid=463283) 2023-01-05 14:15:15,315 cisTarget    INFO     Getting cistromes for Topic13
# 2023-01-05 14:15:22,456 cisTarget    INFO     Done!
# 2023-01-05 14:15:22,460 pycisTarget_wrapper INFO     Created folder : pbmc_tutorial/motifs/CTX_topics_top_3_All
# 2023-01-05 14:15:22,766 pycisTarget_wrapper INFO     Running cisTarget without promoters for topics_top_3
# 2023-01-05 14:15:48,587	INFO worker.py:1519 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (ctx_internal_ray pid=464677) 2023-01-05 14:15:59,829 cisTarget    INFO     Running cisTarget for Topic1 which has 2846 regions
# (ctx_internal_ray pid=464673) 2023-01-05 14:15:59,796 cisTarget    INFO     Running cisTarget for Topic2 which has 2431 regions
# (ctx_internal_ray pid=464671) 2023-01-05 14:16:00,118 cisTarget    INFO     Running cisTarget for Topic3 which has 2605 regions
# (ctx_internal_ray pid=464675) 2023-01-05 14:16:00,226 cisTarget    INFO     Running cisTarget for Topic4 which has 2586 regions
# (ctx_internal_ray pid=464678) 2023-01-05 14:16:00,523 cisTarget    INFO     Running cisTarget for Topic5 which has 2704 regions
# (ctx_internal_ray pid=464676) 2023-01-05 14:16:00,957 cisTarget    INFO     Running cisTarget for Topic6 which has 2517 regions
# (ctx_internal_ray pid=464674) 2023-01-05 14:16:01,194 cisTarget    INFO     Running cisTarget for Topic7 which has 2669 regions
# (ctx_internal_ray pid=464672) 2023-01-05 14:16:01,635 cisTarget    INFO     Running cisTarget for Topic8 which has 2633 regions
# (ctx_internal_ray pid=464673) 2023-01-05 14:16:44,138 cisTarget    INFO     Annotating motifs for Topic2
# (ctx_internal_ray pid=464677) 2023-01-05 14:16:46,394 cisTarget    INFO     Annotating motifs for Topic1
# (ctx_internal_ray pid=464675) 2023-01-05 14:16:47,119 cisTarget    INFO     Annotating motifs for Topic4
# (ctx_internal_ray pid=464673) 2023-01-05 14:16:47,140 cisTarget    INFO     Getting cistromes for Topic2
# (ctx_internal_ray pid=464671) 2023-01-05 14:16:47,389 cisTarget    INFO     Annotating motifs for Topic3
# (ctx_internal_ray pid=464678) 2023-01-05 14:16:47,701 cisTarget    INFO     Annotating motifs for Topic5
# (ctx_internal_ray pid=464673) 2023-01-05 14:16:47,790 cisTarget    INFO     Running cisTarget for Topic9 which has 2576 regions
# (ctx_internal_ray pid=464674) 2023-01-05 14:16:48,017 cisTarget    INFO     Annotating motifs for Topic7
# (ctx_internal_ray pid=464676) 2023-01-05 14:16:48,181 cisTarget    INFO     Annotating motifs for Topic6
# (ctx_internal_ray pid=464672) 2023-01-05 14:16:49,196 cisTarget    INFO     Annotating motifs for Topic8
# (ctx_internal_ray pid=464675) 2023-01-05 14:16:50,759 cisTarget    INFO     Getting cistromes for Topic4
# (ctx_internal_ray pid=464671) 2023-01-05 14:16:50,923 cisTarget    INFO     Getting cistromes for Topic3
# (ctx_internal_ray pid=464677) 2023-01-05 14:16:51,203 cisTarget    INFO     Getting cistromes for Topic1
# (ctx_internal_ray pid=464678) 2023-01-05 14:16:51,197 cisTarget    INFO     Getting cistromes for Topic5
# (ctx_internal_ray pid=464674) 2023-01-05 14:16:51,549 cisTarget    INFO     Getting cistromes for Topic7
# (ctx_internal_ray pid=464671) 2023-01-05 14:16:51,867 cisTarget    INFO     Running cisTarget for Topic10 which has 329 regions
# (ctx_internal_ray pid=464675) 2023-01-05 14:16:51,855 cisTarget    INFO     Running cisTarget for Topic11 which has 2123 regions
# (ctx_internal_ray pid=464678) 2023-01-05 14:16:52,081 cisTarget    INFO     Running cisTarget for Topic12 which has 1996 regions
# (ctx_internal_ray pid=464677) 2023-01-05 14:16:52,537 cisTarget    INFO     Running cisTarget for Topic13 which has 1304 regions
# (ctx_internal_ray pid=464672) 2023-01-05 14:16:52,817 cisTarget    INFO     Getting cistromes for Topic8
# (ctx_internal_ray pid=464674) 2023-01-05 14:16:52,859 cisTarget    INFO     Running cisTarget for Topic14 which has 2590 regions
# (ctx_internal_ray pid=464676) 2023-01-05 14:16:53,378 cisTarget    INFO     Getting cistromes for Topic6
# (ctx_internal_ray pid=464672) 2023-01-05 14:16:54,209 cisTarget    INFO     Running cisTarget for Topic15 which has 1862 regions
# (ctx_internal_ray pid=464676) 2023-01-05 14:16:54,755 cisTarget    INFO     Running cisTarget for Topic16 which has 509 regions
# (ctx_internal_ray pid=464673) 2023-01-05 14:17:29,916 cisTarget    INFO     Annotating motifs for Topic9
# (ctx_internal_ray pid=464671) 2023-01-05 14:17:31,933 cisTarget    INFO     Annotating motifs for Topic10
# (ctx_internal_ray pid=464678) 2023-01-05 14:17:32,120 cisTarget    INFO     Annotating motifs for Topic12
# (ctx_internal_ray pid=464677) 2023-01-05 14:17:32,620 cisTarget    INFO     Annotating motifs for Topic13
# (ctx_internal_ray pid=464674) 2023-01-05 14:17:32,534 cisTarget    INFO     Annotating motifs for Topic14
# (ctx_internal_ray pid=464675) 2023-01-05 14:17:32,994 cisTarget    INFO     Annotating motifs for Topic11
# (ctx_internal_ray pid=464673) 2023-01-05 14:17:33,342 cisTarget    INFO     Getting cistromes for Topic9
# (ctx_internal_ray pid=464672) 2023-01-05 14:17:34,004 cisTarget    INFO     Annotating motifs for Topic15
# (ctx_internal_ray pid=464676) 2023-01-05 14:17:34,358 cisTarget    INFO     Annotating motifs for Topic16
# (ctx_internal_ray pid=464671) 2023-01-05 14:17:35,015 cisTarget    INFO     Getting cistromes for Topic10
# (ctx_internal_ray pid=464678) 2023-01-05 14:17:35,575 cisTarget    INFO     Getting cistromes for Topic12
# (ctx_internal_ray pid=464677) 2023-01-05 14:17:35,741 cisTarget    INFO     Getting cistromes for Topic13
# (ctx_internal_ray pid=464674) 2023-01-05 14:17:35,801 cisTarget    INFO     Getting cistromes for Topic14
# (ctx_internal_ray pid=464675) 2023-01-05 14:17:36,504 cisTarget    INFO     Getting cistromes for Topic11
# (ctx_internal_ray pid=464672) 2023-01-05 14:17:37,160 cisTarget    INFO     Getting cistromes for Topic15
# (ctx_internal_ray pid=464676) 2023-01-05 14:17:37,306 cisTarget    INFO     Getting cistromes for Topic16
# 2023-01-05 14:17:42,519 cisTarget    INFO     Done!
# 2023-01-05 14:17:42,521 pycisTarget_wrapper INFO     Created folder:pbmc_tutorial/motifs/CTX_topics_top_3_No_promoters
# 2023-01-05 14:17:42,804 pycisTarget_wrapper INFO     Running DEM for topics_top_3
# 2023-01-05 14:17:42,805 DEM          INFO     Reading DEM database
# 2023-01-05 14:19:52,523 DEM          INFO     Creating contrast groups
# 2023-01-05 14:20:24,530	INFO worker.py:1519 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (DEM_internal_ray pid=466314) 2023-01-05 14:20:37,953 DEM          INFO     Computing DEM for Topic1
# (DEM_internal_ray pid=466316) 2023-01-05 14:20:38,046 DEM          INFO     Computing DEM for Topic2
# (DEM_internal_ray pid=466315) 2023-01-05 14:20:38,307 DEM          INFO     Computing DEM for Topic3
# (DEM_internal_ray pid=466311) 2023-01-05 14:20:38,514 DEM          INFO     Computing DEM for Topic4
# (DEM_internal_ray pid=466309) 2023-01-05 14:20:38,851 DEM          INFO     Computing DEM for Topic5
# (DEM_internal_ray pid=466313) 2023-01-05 14:20:39,114 DEM          INFO     Computing DEM for Topic6
# (DEM_internal_ray pid=466310) 2023-01-05 14:20:39,471 DEM          INFO     Computing DEM for Topic7
# (DEM_internal_ray pid=466312) 2023-01-05 14:20:40,062 DEM          INFO     Computing DEM for Topic8
# (DEM_internal_ray pid=466316) 2023-01-05 14:20:47,204 DEM          INFO     Computing DEM for Topic9
# (DEM_internal_ray pid=466313) 2023-01-05 14:20:49,017 DEM          INFO     Computing DEM for Topic10
# (DEM_internal_ray pid=466309) 2023-01-05 14:20:49,673 DEM          INFO     Computing DEM for Topic11
# (DEM_internal_ray pid=466315) 2023-01-05 14:20:52,156 DEM          INFO     Computing DEM for Topic12
# (DEM_internal_ray pid=466312) 2023-01-05 14:20:52,840 DEM          INFO     Computing DEM for Topic13
# (DEM_internal_ray pid=466311) 2023-01-05 14:20:54,744 DEM          INFO     Computing DEM for Topic14
# (DEM_internal_ray pid=466310) 2023-01-05 14:20:55,578 DEM          INFO     Computing DEM for Topic15
# (DEM_internal_ray pid=466315) 2023-01-05 14:21:03,046 DEM          INFO     Computing DEM for Topic16
# 2023-01-05 14:22:00,164 DEM          INFO     Forming cistromes
# 2023-01-05 14:22:08,355 DEM          INFO     Done!
# 2023-01-05 14:22:11,108 pycisTarget_wrapper INFO     Created folder : pbmc_tutorial/motifs/DEM_topics_top_3_All
# 2023-01-05 14:22:11,503 pycisTarget_wrapper INFO     Running DEM without promoters for topics_top_3
# 2023-01-05 14:22:25,348 DEM          INFO     Creating contrast groups
# 2023-01-05 14:22:39,883	INFO worker.py:1519 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (DEM_internal_ray pid=467669) 2023-01-05 14:22:53,151 DEM          INFO     Computing DEM for Topic1
# (DEM_internal_ray pid=467671) 2023-01-05 14:22:53,131 DEM          INFO     Computing DEM for Topic2
# (DEM_internal_ray pid=467666) 2023-01-05 14:22:53,430 DEM          INFO     Computing DEM for Topic3
# (DEM_internal_ray pid=467664) 2023-01-05 14:22:53,831 DEM          INFO     Computing DEM for Topic4
# (DEM_internal_ray pid=467665) 2023-01-05 14:22:53,922 DEM          INFO     Computing DEM for Topic5
# (DEM_internal_ray pid=467667) 2023-01-05 14:22:54,260 DEM          INFO     Computing DEM for Topic6
# (DEM_internal_ray pid=467670) 2023-01-05 14:22:54,654 DEM          INFO     Computing DEM for Topic7
# (DEM_internal_ray pid=467668) 2023-01-05 14:22:55,199 DEM          INFO     Computing DEM for Topic8
# (DEM_internal_ray pid=467671) 2023-01-05 14:23:02,469 DEM          INFO     Computing DEM for Topic9
# (DEM_internal_ray pid=467668) 2023-01-05 14:23:03,866 DEM          INFO     Computing DEM for Topic10
# (DEM_internal_ray pid=467665) 2023-01-05 14:23:04,706 DEM          INFO     Computing DEM for Topic11
# (DEM_internal_ray pid=467667) 2023-01-05 14:23:05,342 DEM          INFO     Computing DEM for Topic12
# (DEM_internal_ray pid=467666) 2023-01-05 14:23:05,496 DEM          INFO     Computing DEM for Topic13
# (DEM_internal_ray pid=467664) 2023-01-05 14:23:07,462 DEM          INFO     Computing DEM for Topic14
# (DEM_internal_ray pid=467670) 2023-01-05 14:23:08,880 DEM          INFO     Computing DEM for Topic15
# (DEM_internal_ray pid=467669) 2023-01-05 14:23:14,682 DEM          INFO     Computing DEM for Topic16
# 2023-01-05 14:23:32,953 DEM          INFO     Forming cistromes
# 2023-01-05 14:23:40,517 DEM          INFO     Done!
# 2023-01-05 14:23:43,231 pycisTarget_wrapper INFO     Created folder : pbmc_tutorial/motifs/DEM_topics_top_3_No_promoters
# 2023-01-05 14:23:43,636 pycisTarget_wrapper INFO     Loading cisTarget database for DARs
# 2023-01-05 14:23:43,637 cisTarget    INFO     Reading cisTarget database
# 2023-01-05 14:25:29,327 pycisTarget_wrapper INFO     Running cisTarget for DARs
# 2023-01-05 14:25:43,135	INFO worker.py:1519 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (ctx_internal_ray pid=469009) 2023-01-05 14:25:54,555 cisTarget    INFO     Running cisTarget for B_cells_1 which has 10962 regions
# (ctx_internal_ray pid=469014) 2023-01-05 14:25:54,646 cisTarget    INFO     Running cisTarget for B_cells_2 which has 12434 regions
# (ctx_internal_ray pid=469012) 2023-01-05 14:25:54,930 cisTarget    INFO     Running cisTarget for CD14+_Monocytes which has 30557 regions
# (ctx_internal_ray pid=469008) 2023-01-05 14:25:55,372 cisTarget    INFO     Running cisTarget for CD4_T_cells which has 16280 regions
# (ctx_internal_ray pid=469010) 2023-01-05 14:25:55,667 cisTarget    INFO     Running cisTarget for CD8_T_cells which has 8946 regions
# (ctx_internal_ray pid=469011) 2023-01-05 14:25:56,220 cisTarget    INFO     Running cisTarget for Dendritic_cells which has 27228 regions
# (ctx_internal_ray pid=469013) 2023-01-05 14:25:56,624 cisTarget    INFO     Running cisTarget for FCGR3A+_Monocytes which has 27097 regions
# (ctx_internal_ray pid=469007) 2023-01-05 14:25:57,025 cisTarget    INFO     Running cisTarget for NK_cells which has 8121 regions
# (ctx_internal_ray pid=469010) 2023-01-05 14:26:44,625 cisTarget    INFO     Annotating motifs for CD8_T_cells
# (ctx_internal_ray pid=469009) 2023-01-05 14:26:45,964 cisTarget    INFO     Annotating motifs for B_cells_1
# (ctx_internal_ray pid=469014) 2023-01-05 14:26:46,208 cisTarget    INFO     Annotating motifs for B_cells_2
# (ctx_internal_ray pid=469007) 2023-01-05 14:26:47,141 cisTarget    INFO     Annotating motifs for NK_cells
# (ctx_internal_ray pid=469010) 2023-01-05 14:26:48,878 cisTarget    INFO     Getting cistromes for CD8_T_cells
# (ctx_internal_ray pid=469008) 2023-01-05 14:26:50,033 cisTarget    INFO     Annotating motifs for CD4_T_cells
# (ctx_internal_ray pid=469009) 2023-01-05 14:26:50,485 cisTarget    INFO     Getting cistromes for B_cells_1
# (ctx_internal_ray pid=469014) 2023-01-05 14:26:50,996 cisTarget    INFO     Getting cistromes for B_cells_2
# (ctx_internal_ray pid=469007) 2023-01-05 14:26:51,158 cisTarget    INFO     Getting cistromes for NK_cells
# (ctx_internal_ray pid=469008) 2023-01-05 14:26:55,270 cisTarget    INFO     Getting cistromes for CD4_T_cells
# (ctx_internal_ray pid=469011) 2023-01-05 14:26:55,769 cisTarget    INFO     Annotating motifs for Dendritic_cells
# (ctx_internal_ray pid=469013) 2023-01-05 14:26:56,024 cisTarget    INFO     Annotating motifs for FCGR3A+_Monocytes
# (ctx_internal_ray pid=469012) 2023-01-05 14:26:57,295 cisTarget    INFO     Annotating motifs for CD14+_Monocytes
# (ctx_internal_ray pid=469011) 2023-01-05 14:27:03,129 cisTarget    INFO     Getting cistromes for Dendritic_cells
# (ctx_internal_ray pid=469013) 2023-01-05 14:27:03,269 cisTarget    INFO     Getting cistromes for FCGR3A+_Monocytes
# (ctx_internal_ray pid=469012) 2023-01-05 14:27:05,009 cisTarget    INFO     Getting cistromes for CD14+_Monocytes
# 2023-01-05 14:27:21,378 cisTarget    INFO     Done!
# 2023-01-05 14:27:21,380 pycisTarget_wrapper INFO     Created folder : pbmc_tutorial/motifs/CTX_DARs_All
# 2023-01-05 14:27:21,532 pycisTarget_wrapper INFO     Running cisTarget without promoters for DARs
# 2023-01-05 14:27:48,078	INFO worker.py:1519 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (ctx_internal_ray pid=470320) 2023-01-05 14:27:59,449 cisTarget    INFO     Running cisTarget for B_cells_1 which has 9206 regions
# (ctx_internal_ray pid=470315) 2023-01-05 14:27:59,584 cisTarget    INFO     Running cisTarget for B_cells_2 which has 10870 regions
# (ctx_internal_ray pid=470321) 2023-01-05 14:27:59,834 cisTarget    INFO     Running cisTarget for CD14+_Monocytes which has 27627 regions
# (ctx_internal_ray pid=470319) 2023-01-05 14:28:00,212 cisTarget    INFO     Running cisTarget for CD4_T_cells which has 12424 regions
# (ctx_internal_ray pid=470322) 2023-01-05 14:28:00,592 cisTarget    INFO     Running cisTarget for CD8_T_cells which has 7661 regions
# (ctx_internal_ray pid=470317) 2023-01-05 14:28:01,046 cisTarget    INFO     Running cisTarget for Dendritic_cells which has 24850 regions
# (ctx_internal_ray pid=470316) 2023-01-05 14:28:01,403 cisTarget    INFO     Running cisTarget for FCGR3A+_Monocytes which has 24684 regions
# (ctx_internal_ray pid=470318) 2023-01-05 14:28:01,755 cisTarget    INFO     Running cisTarget for NK_cells which has 6823 regions
# 2023-01-05 14:28:42,478	WARNING worker.py:1839 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: 4267bd8f262060d52680a7b3af006ff37350f66e01000000 Worker ID: 05c90efb746b4ac3a79040c6df27d815bb385eb7a99019793bc0e9d1 Node ID: 31bbd73fbcde8527d4145bdaa8258d42d03e1c1bc06d24f3306519b5 Worker IP address: 192.168.169.113 Worker port: 43801 Worker PID: 470322 Worker exit type: SYSTEM_ERROR Worker exit detail: Worker unexpectedly exits with a connection error code 2. End of file. There are some potential root causes. (1) The process is killed by SIGKILL by OOM killer due to high memory usage. (2) ray stop --force is called. (3) The worker is crashed unexpectedly due to SIGSEGV or other unexpected errors.
# 2023-01-05 14:28:43,968	WARNING worker.py:1839 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: 2d833dcdfb92866df6ca80d2855914ee5678180301000000 Worker ID: b11cb343b86945ea60321edbd3bc73904cf14ebe32bf56fedf206675 Node ID: 31bbd73fbcde8527d4145bdaa8258d42d03e1c1bc06d24f3306519b5 Worker IP address: 192.168.169.113 Worker port: 43351 Worker PID: 470315 Worker exit type: SYSTEM_ERROR Worker exit detail: Worker unexpectedly exits with a connection error code 2. End of file. There are some potential root causes. (1) The process is killed by SIGKILL by OOM killer due to high memory usage. (2) ray stop --force is called. (3) The worker is crashed unexpectedly due to SIGSEGV or other unexpected errors.
# (ctx_internal_ray pid=470320) 2023-01-05 14:28:51,390 cisTarget    INFO     Annotating motifs for B_cells_1
# (ctx_internal_ray pid=470318) 2023-01-05 14:28:52,562 cisTarget    INFO     Annotating motifs for NK_cells
# (ctx_internal_ray pid=470319) 2023-01-05 14:28:53,229 cisTarget    INFO     Annotating motifs for CD4_T_cells
# (ctx_internal_ray pid=470320) 2023-01-05 14:28:55,739 cisTarget    INFO     Getting cistromes for B_cells_1
# (ctx_internal_ray pid=470318) 2023-01-05 14:28:56,644 cisTarget    INFO     Getting cistromes for NK_cells
# (ctx_internal_ray pid=471086) 2023-01-05 14:28:57,269 cisTarget    INFO     Running cisTarget for CD8_T_cells which has 7661 regions
# (ctx_internal_ray pid=471091) 2023-01-05 14:28:57,762 cisTarget    INFO     Running cisTarget for B_cells_2 which has 10870 regions
# (ctx_internal_ray pid=470319) 2023-01-05 14:28:58,370 cisTarget    INFO     Getting cistromes for CD4_T_cells
# (ctx_internal_ray pid=470317) 2023-01-05 14:28:59,463 cisTarget    INFO     Annotating motifs for Dendritic_cells
# (ctx_internal_ray pid=470316) 2023-01-05 14:29:00,558 cisTarget    INFO     Annotating motifs for FCGR3A+_Monocytes
# (ctx_internal_ray pid=470321) 2023-01-05 14:29:01,940 cisTarget    INFO     Annotating motifs for CD14+_Monocytes
# (ctx_internal_ray pid=470317) 2023-01-05 14:29:06,504 cisTarget    INFO     Getting cistromes for Dendritic_cells
# (ctx_internal_ray pid=470316) 2023-01-05 14:29:07,534 cisTarget    INFO     Getting cistromes for FCGR3A+_Monocytes
# (ctx_internal_ray pid=470321) 2023-01-05 14:29:09,889 cisTarget    INFO     Getting cistromes for CD14+_Monocytes
# (ctx_internal_ray pid=471086) 2023-01-05 14:29:40,987 cisTarget    INFO     Annotating motifs for CD8_T_cells
# (ctx_internal_ray pid=471091) 2023-01-05 14:29:42,508 cisTarget    INFO     Annotating motifs for B_cells_2
# (ctx_internal_ray pid=471086) 2023-01-05 14:29:44,838 cisTarget    INFO     Getting cistromes for CD8_T_cells
# (ctx_internal_ray pid=471091) 2023-01-05 14:29:46,732 cisTarget    INFO     Getting cistromes for B_cells_2
# 2023-01-05 14:29:57,692 cisTarget    INFO     Done!
# 2023-01-05 14:29:57,696 pycisTarget_wrapper INFO     Created folder:pbmc_tutorial/motifs/CTX_DARs_No_promoters
# 2023-01-05 14:29:57,856 pycisTarget_wrapper INFO     Running DEM for DARs
# 2023-01-05 14:29:57,857 DEM          INFO     Reading DEM database
# 2023-01-05 14:32:31,305 DEM          INFO     Creating contrast groups
# 2023-01-05 14:32:58,996	INFO worker.py:1519 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (DEM_internal_ray pid=472083) 2023-01-05 14:33:15,045 DEM          INFO     Computing DEM for B_cells_1
# (DEM_internal_ray pid=472079) 2023-01-05 14:33:15,250 DEM          INFO     Computing DEM for CD8_T_cells
# (DEM_internal_ray pid=472084) 2023-01-05 14:33:15,890 DEM          INFO     Computing DEM for B_cells_2
# (DEM_internal_ray pid=472081) 2023-01-05 14:33:16,537 DEM          INFO     Computing DEM for NK_cells
# (DEM_internal_ray pid=472080) 2023-01-05 14:33:17,569 DEM          INFO     Computing DEM for CD4_T_cells
# (DEM_internal_ray pid=472082) 2023-01-05 14:33:25,369 DEM          INFO     Computing DEM for Dendritic_cells
# (DEM_internal_ray pid=472085) 2023-01-05 14:33:26,173 DEM          INFO     Computing DEM for FCGR3A+_Monocytes
# (DEM_internal_ray pid=472086) 2023-01-05 14:33:26,752 DEM          INFO     Computing DEM for CD14+_Monocytes
# 2023-01-05 14:34:40,666 DEM          INFO     Forming cistromes
# 2023-01-05 14:34:43,302 DEM          INFO     Done!
# 2023-01-05 14:34:45,177 pycisTarget_wrapper INFO     Created folder : pbmc_tutorial/motifs/DEM_DARs_All
# 2023-01-05 14:34:45,280 pycisTarget_wrapper INFO     Running DEM without promoters for DARs
# 2023-01-05 14:34:59,624 DEM          INFO     Creating contrast groups
# 2023-01-05 14:35:13,551	INFO worker.py:1519 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (DEM_internal_ray pid=473374) 2023-01-05 14:35:28,955 DEM          INFO     Computing DEM for B_cells_1
# (DEM_internal_ray pid=473369) 2023-01-05 14:35:29,717 DEM          INFO     Computing DEM for CD8_T_cells
# (DEM_internal_ray pid=473372) 2023-01-05 14:35:29,806 DEM          INFO     Computing DEM for B_cells_2
# (DEM_internal_ray pid=473373) 2023-01-05 14:35:30,487 DEM          INFO     Computing DEM for NK_cells
# (DEM_internal_ray pid=473370) 2023-01-05 14:35:30,845 DEM          INFO     Computing DEM for CD4_T_cells
# (DEM_internal_ray pid=473371) 2023-01-05 14:35:37,418 DEM          INFO     Computing DEM for FCGR3A+_Monocytes
# (DEM_internal_ray pid=473375) 2023-01-05 14:35:37,968 DEM          INFO     Computing DEM for Dendritic_cells
# (DEM_internal_ray pid=473368) 2023-01-05 14:35:38,644 DEM          INFO     Computing DEM for CD14+_Monocytes
# 2023-01-05 14:36:42,167 DEM          INFO     Forming cistromes
# 2023-01-05 14:36:44,419 DEM          INFO     Done!
# 2023-01-05 14:36:46,393 pycisTarget_wrapper INFO     Created folder : pbmc_tutorial/motifs/DEM_DARs_No_promoters
# 2023-01-05 14:36:46,487 pycisTarget_wrapper INFO     Saving object
# 2023-01-05 14:57:14,895 pycisTarget_wrapper INFO     Finished! Took 60.0089680870374 minutes

# %%
import dill
menr = dill.load(open(os.path.join(work_dir, 'motifs/menr.pkl'), 'rb'))

# %%
#menr['DEM_topics_otsu_All'].DEM_results('Topic8')

# %% [markdown]
# ## 6. SCENIC+ analysis

# %%
import dill
import scanpy as sc
import pandas as pd
import os
import warnings
warnings.filterwarnings("ignore")
import pandas
import pyranges
# Set stderr to null to avoid strange messages from ray
import sys
_stderr = sys.stderr
null = open(os.devnull,'wb')
tmp_dir = '/cellar/users/aklie/tmp/'

# %% [markdown]
# Need to laod in all the data and jump through a few hoops to create a scenic+ object. They are familiar hoops at least, see the scATAC analysis section

# %%
adata = sc.read_h5ad(os.path.join(work_dir, 'scRNA/adata.h5ad'))
cistopic_obj = dill.load(open(os.path.join(work_dir, 'scATAC/cistopic_obj_50_iter_model.pkl'), 'rb'))
menr = dill.load(open(os.path.join(work_dir, 'motifs/menr.pkl'), 'rb'))

# %%
adata.var_names_make_unique()

# %%
# For the mouse ENCODE 4 data, only a subset of the cells were from the 10x multiome kit
print("Do some barcode mapping acrobatics...")
adata = adata[adata.obs["technology"] == "10x"]
adata.obs['celltype'] = adata.obs['celltypes'].astype(str) # set data type of the celltype column to str, otherwise the export_pseudobulk function will complain.
adata.obs["celltype"].value_counts(dropna=False)
# Out:
# Do some barcode mapping acrobatics...
# Cortex             22227
# Endothelial         4965
# Medulla             3370
# Stromal             1406
# Macrophages          971
# Adipocytes           872
# Fibroblast           833
# Sox10+               216
# Smooth_muscle         63
# Capsule               57
# Hepatocyte            15
# Skeletal_muscle        1
# Name: celltype, dtype: int64

# %% [markdown]
# Next you should make sure that you have barcodes in your cell metadata that match the barcodes in your fragment files. This can be tricky, but you can use the following as examples

# %%
# Read in some extra metadata to match cells to samples and toconvert barcodes
snatac_meta = pd.read_csv("/cellar/users/aklie/data/igvf/topic_grn_links/mouse_adrenal/encode/enc4_mouse_snatac_metadata.tsv", sep="\t")
acc_mp = snatac_meta.set_index("rna_library_accession")["file_accession"]
adata.obs["sample_id"] = adata.obs["library_accession"].map(acc_mp).values
adata.obs["sample_id"].value_counts(dropna=False)
# Out:
# ENCFF683IBE    5270
# ENCFF176LJV    5163
# ENCFF035SPT    4584
# ENCFF622EUO    4507
# ENCFF101BLM    4324
# ENCFF119IVK    3989
# ENCFF042ZJI    3987
# ENCFF187VMN    3172
# Name: sample_id, dtype: int64

# %%
# Map the RNA barcodes from the anndata to the ATAC barcodes present in the fragment file
rna_bcs = pd.read_csv("/cellar/users/aklie/data/igvf/topic_grn_links/mouse_adrenal/encode/gene_exp_737K-arc-v1.txt", header=None)[0].values # read in the set of external rna barcodes
atac_bcs = pd.read_csv("/cellar/users/aklie/data/igvf/topic_grn_links/mouse_adrenal/encode/atac_737K-arc-v1.txt", header=None)[0].values # Read in the set of external atac barcodes
bcs = pd.DataFrame(data={"rna_bcs": rna_bcs, "atac_bcs": atac_bcs}) # create a dataframe with both
COMPLEMENT_DNA = {"A": "T", "C": "G", "G": "C", "T": "A"} # the fragment files contain reverse complements of the atac bcs, need to get these
bcs["atac_bcs_rc"] = ["".join(COMPLEMENT_DNA.get(base, base) for base in reversed(bc)) for bc in bcs["atac_bcs"]]
bc_map = bcs.set_index("rna_bcs")["atac_bcs_rc"] # create a map for going from rna bcs to atac bcs in fragment files

# %%
# Map the rna bcs in the cell metadata to the fragment file atac barcodes
adata.obs["rna_bc"] = [row[0] for row in adata.obs["cellID"].str.split(".")] # grab the RNA barcodes from the anndata metadata
adata.obs["atac_bc"] = adata.obs["rna_bc"].map(bc_map) # map the
adata.obs["atac_bc_sample"] = adata.obs["atac_bc"] + "-" + adata.obs["sample_id"]
adata.obs["barcode"] = adata.obs["atac_bc"]
adata.obs = adata.obs.set_index("atac_bc_sample")

# %%
adata.obs_names.str.replace(".", "-").isin(cistopic_obj.cell_names).sum()
# Out:
# 33799

# %%
adata.obs_names.isin(cistopic_obj.cell_names).sum()
# Out:
# 33799

# %%
tf_list = "/cellar/users/aklie/opt/shared/SCENIC/tf_lists/allTFs_mm.txt"
tfs = pd.read_csv(tf_list, header=None)[0].values

# %%
adata.var.index.isin(tfs).sum()
# Out:
# 1851

# %%
sc.pp.filter_genes(adata, min_cells=3)
adata.var['mt'] = adata.var_names.str.startswith('mt-')  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

# %%
adata.var
# Out:
#                       features  n_cells     mt  n_cells_by_counts  \
# Xkr4                      Xkr4     4469  False               4469
# Gm1992                  Gm1992      216  False                216
# Gm19938                Gm19938      630  False                630
# Gm37381                Gm37381      129  False                129
# Rp1                        Rp1      499  False                499
# ...                        ...      ...    ...                ...
# Ccl27                    Ccl27        9  False                  9
# CR974586.5          CR974586.5        9  False                  9
# Gm10931                Gm10931       10  False                 10
# CAAA01147332.1  CAAA01147332.1      232  False                232
# AC149090.1          AC149090.1    24157  False              24157
#
#                 mean_counts  pct_dropout_by_counts  total_counts
# Xkr4               0.506201              87.229969       17715.0
# Gm1992             0.006801              99.382787         238.0
# Gm19938            0.021002              98.199794         735.0
# Gm37381            0.003743              99.631386         131.0
# Rp1                0.016202              98.574123         567.0
# ...                     ...                    ...           ...
# Ccl27              0.000257              99.974283           9.0
# CR974586.5         0.000257              99.974283           9.0
# Gm10931            0.000286              99.971425          10.0
# CAAA01147332.1     0.006658              99.337067         233.0
# AC149090.1         2.041262              30.972111       71436.0
#
# [31281 rows x 7 columns]

# %% [markdown]
# Now we can create our object and save it, this needs a lot of memory in making the matrix sparse

# %%
from scenicplus.scenicplus_class import create_SCENICPLUS_object
import numpy as np
scplus_obj = create_SCENICPLUS_object(
    GEX_anndata = adata.raw.to_adata(),
    cisTopic_obj = cistopic_obj,
    menr = menr,
)
scplus_obj.X_EXP = np.array(scplus_obj.X_EXP.todense())
scplus_obj
# Out:
# 2023-01-30 17:52:22,829 cisTopic     INFO     Imputing drop-outs
# 2023-01-30 17:55:31,336 cisTopic     INFO     Scaling
# 2023-01-30 17:57:39,094 cisTopic     INFO     Keep non zero rows
# 2023-01-30 18:00:07,539 cisTopic     INFO     Imputed accessibility sparsity: 0.7026057290369099
# 2023-01-30 18:00:07,540 cisTopic     INFO     Create CistopicImputedFeatures object
# 2023-01-30 18:00:07,541 cisTopic     INFO     Making matrix sparse

# %%
if not os.path.exists(os.path.join(work_dir, 'scenicplus')):
    os.makedirs(os.path.join(work_dir, 'scenicplus'))

# %%
dill.dump(scplus_obj, open(os.path.join(work_dir, 'scenicplus/scplus_obj_pre.pkl'), 'wb'), protocol=-1)

# %% [markdown]
# Load the saved object and check for overlap with gene annotations. Use this to inform your seletion in the scenicplus run script (10)

# %%
scplus_obj = dill.load(open(os.path.join(work_dir, 'scenicplus/scplus_obj_pre.pkl'), 'rb'))

# %%
scplus_obj.metadata_genes.index = scplus_obj.metadata_genes["_index"]

# %%
scplus_obj.gene_names.isin(tfs).sum()
# Out:
# 1851

# %%
scplus_obj.X_ACC.shape
# Out:
# (675280, 33799)

# %%
scplus_obj.X_EXP.shape
# Out:
# (33799, 47721)

# %%
scplus_obj.metadata_genes
# Out:
#                 _index
# _index
# Xkr4              Xkr4
# Gm18956        Gm18956
# Gm1992          Gm1992
# Gm7341          Gm7341
# Gm19938        Gm19938
# ...                ...
# AC124606.1  AC124606.1
# AC133095.2  AC133095.2
# AC133095.1  AC133095.1
# AC234645.1  AC234645.1
# AC149090.1  AC149090.1
#
# [47721 rows x 1 columns]

# %%
ensembl_version_dict = {'105': 'http://www.ensembl.org',
                        '104': 'http://may2021.archive.ensembl.org/',
                        '103': 'http://feb2021.archive.ensembl.org/',
                        '102': 'http://nov2020.archive.ensembl.org/',
                        '101': 'http://aug2020.archive.ensembl.org/',
                        '100': 'http://apr2020.archive.ensembl.org/',
                        '99': 'http://jan2020.archive.ensembl.org/',
                        '98': 'http://sep2019.archive.ensembl.org/',
                        '97': 'http://jul2019.archive.ensembl.org/',
                        '96': 'http://apr2019.archive.ensembl.org/',
                        '95': 'http://jan2019.archive.ensembl.org/',
                        '94': 'http://oct2018.archive.ensembl.org/',
                        '93': 'http://jul2018.archive.ensembl.org/',
                        '92': 'http://apr2018.archive.ensembl.org/',
                        '91': 'http://dec2017.archive.ensembl.org/',
                        '90': 'http://aug2017.archive.ensembl.org/',
                        '89': 'http://may2017.archive.ensembl.org/',
                        '88': 'http://mar2017.archive.ensembl.org/',
                        '87': 'http://dec2016.archive.ensembl.org/',
                        '86': 'http://oct2016.archive.ensembl.org/',
                        '80': 'http://may2015.archive.ensembl.org/',
                        '77': 'http://oct2014.archive.ensembl.org/',
                        '75': 'http://feb2014.archive.ensembl.org/',
                        '54': 'http://may2009.archive.ensembl.org/'}

import pybiomart as pbm
def test_ensembl_host(scplus_obj, host, species):
    dataset = pbm.Dataset(name=species+'_gene_ensembl',  host=host)
    annot = dataset.query(attributes=['chromosome_name', 'transcription_start_site', 'strand', 'external_gene_name', 'transcript_biotype'])
    annot.columns = ['Chromosome', 'Start', 'Strand', 'Gene', 'Transcript_type']
    annot['Chromosome'] = annot['Chromosome'].astype('str')
    filter = annot['Chromosome'].str.contains('CHR|GL|JH|MT')
    annot = annot[~filter]
    annot.columns=['Chromosome', 'Start', 'Strand', 'Gene', 'Transcript_type']
    gene_names_release = set(annot['Gene'].tolist())
    ov=len([x for x in scplus_obj.gene_names if x in gene_names_release])
    print('Genes recovered: ' + str(ov) + ' out of ' + str(len(scplus_obj.gene_names)))
    return ov

n_overlap = {}
for version in ensembl_version_dict.keys():
    print(f'host: {version}')
    try:
        n_overlap[version] =  test_ensembl_host(scplus_obj, ensembl_version_dict[version], 'mmusculus')
    except:
        print('Host not reachable')
v = sorted(n_overlap.items(), key=lambda item: item[1], reverse=True)[0][0]
print(f"version: {v} has the largest overlap, use {ensembl_version_dict[v]} as biomart host")
# Out:
# host: 105
# Genes recovered: 44022 out of 47721
# host: 104
# Genes recovered: 44138 out of 47721
# host: 103
# Genes recovered: 44207 out of 47721
# host: 102
# Genes recovered: 45597 out of 47721
# host: 101
# Host not reachable
# host: 100
# Host not reachable
# host: 99
# Host not reachable
# host: 98
# Genes recovered: 45862 out of 47721
# host: 97
# Host not reachable
# host: 96
# Host not reachable
# host: 95
# Host not reachable
# host: 94
# Host not reachable
# host: 93
# Host not reachable
# host: 92
# Host not reachable
# host: 91
# Host not reachable
# host: 90
# Host not reachable
# host: 89
# Host not reachable
# host: 88
# Host not reachable
# host: 87
# Host not reachable
# host: 86
# Host not reachable
# host: 80
# Host not reachable
# host: 77
# Host not reachable
# host: 75
# Host not reachable
# host: 54
# Host not reachable
# version: 98 has the largest overlap, use http://sep2019.archive.ensembl.org/ as biomart host

# %%
biomart_host = "http://sep2019.archive.ensembl.org/"

# %%
tf_list = "/cellar/users/aklie/opt/shared/SCENIC/tf_lists/allTFs_mm.txt"

# %%
# !wget -O mouse_adrenal/bedToBigBed http://hgdownload.soe.ucsc.edu/admin/exe/linux.x86_64/bedToBigBed
# !chmod +x mouse_adrenal/bedToBigBed
# Out:
# --2023-01-31 17:51:19--  http://hgdownload.soe.ucsc.edu/admin/exe/linux.x86_64/bedToBigBed
# Resolving hgdownload.soe.ucsc.edu (hgdownload.soe.ucsc.edu)... 128.114.119.163
# Connecting to hgdownload.soe.ucsc.edu (hgdownload.soe.ucsc.edu)|128.114.119.163|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9575968 (9.1M)
# Saving to: ‘mouse_adrenal/bedToBigBed’
#
# mouse_adrenal/bedTo 100%[===================>]   9.13M  30.1MB/s    in 0.3s
#
# 2023-01-31 17:51:19 (30.1 MB/s) - ‘mouse_adrenal/bedToBigBed’ saved [9575968/9575968]

# %%
#scplus_obj.dr_cell['GEX_X_pca'] = scplus_obj.dr_cell['GEX_X_pca'].iloc[:, 0:2]
#scplus_obj.dr_cell['GEX_rep'] = scplus_obj.dr_cell['GEX_rep'].iloc[:, 0:2]

# %%
from scenicplus.wrappers.run_scenicplus import run_scenicplus
try:
    run_scenicplus(
        scplus_obj = scplus_obj,
        variable = ['GEX_celltypes'],
        species = 'mmusculus',
        assembly = 'mm10',
        tf_file = tf_list,
        save_path = os.path.join(work_dir, 'scenicplus'),
        biomart_host = biomart_host,
        upstream = [1000, 150000],
        downstream = [1000, 150000],
        calculate_TF_eGRN_correlation = True,
        calculate_DEGs_DARs = True,
        export_to_loom_file = True,
        export_to_UCSC_file = True,
        path_bedToBigBed = '../mouse_adrenal',
        n_cpu = 4,
        _temp_dir = os.path.join(tmp_dir, 'ray_spill'))
except Exception as e:
    #in case of failure, still save the object
    dill.dump(scplus_obj, open(os.path.join(work_dir, 'scenicplus/scplus_obj.pkl'), 'wb'), protocol=-1)
    raise(e)
# Out:
# 2023-02-01 09:34:33,476 SCENIC+_wrapper INFO     mouse_adrenal/scenicplus folder already exists.
# 2023-02-01 09:34:33,477 SCENIC+_wrapper INFO     Merging cistromes
# 2023-02-01 09:38:30,277 SCENIC+_wrapper INFO     Getting search space
# 2023-02-01 09:38:34,446 R2G          INFO     Downloading gene annotation from biomart dataset: mmusculus_gene_ensembl
# 2023-02-01 09:39:36,479 R2G          INFO     Downloading chromosome sizes from: http://hgdownload.cse.ucsc.edu/goldenPath/mm10/bigZips/mm10.chrom.sizes
# 2023-02-01 09:39:36,973 R2G          INFO     Extending promoter annotation to 10 bp upstream and 10 downstream
# 2023-02-01 09:39:38,116 R2G          INFO     Extending search space to:
#             						150000 bp downstream of the end of the gene.
#             						150000 bp upstream of the start of the gene.
# 2023-02-01 09:39:43,989 R2G          INFO     Intersecting with regions.
# join: Strand data from other will be added as strand data to self.
# If this is undesired use the flag apply_strand_suffix=False.
# To turn off the warning set apply_strand_suffix to True or False.
# 2023-02-01 09:39:46,566 R2G          INFO     Calculating distances from region to gene
# 2023-02-01 09:50:07,617 R2G          INFO     Imploding multiple entries per region and gene
# 2023-02-01 10:09:54,444 R2G          INFO     Done!
# 2023-02-01 10:09:56,112 SCENIC+_wrapper INFO     Inferring region to gene relationships
# 2023-02-01 10:09:57,135 R2G          INFO     Calculating region to gene importances, using GBM method

# %% [markdown]
# # Scratch

# %% [markdown]
# ## 3. scATAC-seq analysis

# %%
test_fragments_dict = {"ENCFF187VMN": fragments_dict["ENCFF187VMN"]}
test_cell_data = cell_data[cell_data["sample_id"] == "ENCFF187VMN"]
test_cell_data["barcode"] = test_cell_data["atac_bc"]
test_cell_data = test_cell_data.set_index("atac_bc")
test_fragments = pd.read_csv(test_fragments_dict["ENCFF187VMN"], sep="\t", header=None)
test_cell_data["barcode"].isin(test_fragments[3]).sum()

# %%
import gc
import logging
import os
import re
import subprocess
import sys
from typing import Dict, List, Optional, Union
import numpy as np
import pandas as pd
import pyBigWig
import pyranges as pr

def export_pseudobulk_one_sample(
    cell_data: pd.DataFrame,
    group: str,
    fragments_df_dict: Dict[str, pd.DataFrame],
    chromsizes: pr.PyRanges,
    bigwig_path: str,
    bed_path: str,
    sample_id_col: Optional[str] = "sample_id",
    normalize_bigwig: Optional[bool] = True,
    remove_duplicates: Optional[bool] = True,
    split_pattern: Optional[str] = "___",
):
    """
    Create pseudobulk as bed and bigwig from single cell fragments file given a barcode annotation and a group.
    Parameters
    ---------
    cell_data: pd.DataFrame
            A cell metadata :class:`pd.Dataframe` containing barcodes, their annotation and their sample of origin.
    group: str
            A character string indicating the group for which pseudobulks will be created.
    fragments_df_dict: dict
            A dictionary containing data frames as values with 'Chromosome', 'Start', 'End', 'Name', and 'Score' as columns; and sample label
            as keys. 'Score' indicates the number of times that a fragments is found assigned to that barcode.
    chromsizes: pr.PyRanges
            A :class:`pr.PyRanges` containing size of each column, containing 'Chromosome', 'Start' and 'End' columns.
    bigwig_path: str
            Path to folder where the bigwig file will be saved.
    bed_path: str
            Path to folder where the fragments bed file will be saved.
    sample_id_col: str, optional
            Name of the column containing the sample name per barcode in the input :class:`CistopicObject.cell_data` or class:`pd.DataFrame`. Default: 'sample_id'.
    normalize_bigwig: bool, optional
            Whether bigwig files should be CPM normalized. Default: True.
    remove_duplicates: bool, optional
            Whether duplicates should be removed before converting the data to bigwig.
    split_pattern: str
            Pattern to split cell barcode from sample id. Default: ___ .
    """
    # Create logger
    level = logging.INFO
    log_format = "%(asctime)s %(name)-12s %(levelname)-8s %(message)s"
    handlers = [logging.StreamHandler(stream=sys.stdout)]
    logging.basicConfig(level=level, format=log_format, handlers=handlers)
    log = logging.getLogger("cisTopic")

    log.info("Creating pseudobulk for " + str(group))
    group_fragments_list = []
    group_fragments_dict = {}
    for sample_id in fragments_df_dict:
        sample_data = cell_data[cell_data.loc[:, sample_id_col].isin([sample_id])]
        if "barcode" in sample_data:
            sample_data.index = sample_data["barcode"].tolist()
        else:
            sample_data.index = prepare_tag_cells(
                sample_data.index.tolist(), split_pattern
            )
        group_var = sample_data.iloc[:, 0]
        barcodes = group_var[group_var.isin([group])].index.tolist()
        print(barcodes)
        fragments_df = fragments_df_dict[sample_id]
        group_fragments = fragments_df.loc[fragments_df["Name"].isin(barcodes)]
        if len(fragments_df_dict) > 1:
            group_fragments_dict[sample_id] = group_fragments

    if len(fragments_df_dict) > 1:
        group_fragments_list = [
            group_fragments_dict[list(group_fragments_dict.keys())[x]]
            for x in range(len(fragments_df_dict))
        ]
        group_fragments = group_fragments_list[0].append(group_fragments_list[1:])

    del group_fragments_dict
    del group_fragments_list
    del fragments_df
    gc.collect()

    group_pr = pr.PyRanges(group_fragments)
    if isinstance(bigwig_path, str):
        bigwig_path_group = os.path.join(bigwig_path, str(group) + ".bw")
        if remove_duplicates:
            group_pr.to_bigwig(
                path=bigwig_path_group,
                chromosome_sizes=chromsizes,
                rpm=normalize_bigwig,
            )
        else:
            group_pr.to_bigwig(
                path=bigwig_path_group,
                chromosome_sizes=chromsizes,
                rpm=normalize_bigwig,
                value_col="Score",
            )
    if isinstance(bed_path, str):
        print("here")
        print(group_pr)
        bed_path_group = os.path.join(bed_path, str(group) + ".bed.gz")
        group_pr.to_bed(
            path=bed_path_group, keep=False, compression="infer", chain=False
        )

    log.info(str(group) + " done!")

# %%
from pycisTopic.cistopic_class import *
from pycisTopic.pseudobulk_peak_calling import export_pseudobulk_ray
from pycisTopic.utils import read_fragments_from_file, prepare_tag_cells
def export_pseudobulk(
    input_data: Union["CistopicObject", pd.DataFrame, Dict[str, pd.DataFrame]],
    variable: str,
    chromsizes: Union[pd.DataFrame, pr.PyRanges],
    bed_path: str,
    bigwig_path: str,
    path_to_fragments: Optional[Dict[str, str]] = None,
    sample_id_col: Optional[str] = "sample_id",
    n_cpu: Optional[int] = 1,
    normalize_bigwig: Optional[bool] = True,
    remove_duplicates: Optional[bool] = True,
    split_pattern: Optional[str] = "___",
    use_polars: Optional[bool] = True,
    **kwargs
):
    """
    Create pseudobulks as bed and bigwig from single cell fragments file given a barcode annotation.
    Parameters
    ---------
    input_data: CistopicObject or pd.DataFrame
            A :class:`CistopicObject` containing the specified `variable` as a column in :class:`CistopicObject.cell_data` or a cell metadata
            :class:`pd.DataFrame` containing barcode as rows, containing the specified `variable` as a column (additional columns are
            possible) and a `sample_id` column. Index names must contain the BARCODE (e.g. ATGTCGTC-1), additional tags are possible separating with -
            (e.g. ATGCTGTGCG-1-Sample_1). The levels in the sample_id column must agree with the keys in the path_to_fragments dictionary.
            Alternatively, if the cell metadata contains a column named barcode it will be used instead of the index names.
    variable: str
            A character string indicating the column that will be used to create the different group pseudobulk. It must be included in
            the cell metadata provided as input_data.
    chromsizes: pd.DataFrame or pr.PyRanges
            A data frame or :class:`pr.PyRanges` containing size of each chromosome, containing 'Chromosome', 'Start' and 'End' columns.
    bed_path: str
            Path to folder where the fragments bed files per group will be saved. If None, files will not be generated.
    bigwig_path: str
            Path to folder where the bigwig files per group will be saved. If None, files will not be generated.
    path_to_fragments: str or dict, optional
            A dictionary of character strings, with sample name as names indicating the path to the fragments file/s from which pseudobulk profiles have to
            be created. If a :class:`CistopicObject` is provided as input it will be ignored, but if a cell metadata :class:`pd.DataFrame` is provided it
            is necessary to provide it. The keys of the dictionary need to match with the sample_id tag added to the index names of the input data frame.
    sample_id_col: str, optional
            Name of the column containing the sample name per barcode in the input :class:`CistopicObject.cell_data` or class:`pd.DataFrame`. Default: 'sample_id'.
    n_cpu: int, optional
            Number of cores to use. Default: 1.
    normalize_bigwig: bool, optional
            Whether bigwig files should be CPM normalized. Default: True.
    remove_duplicates: bool, optional
            Whether duplicates should be removed before converting the data to bigwig.
    split_pattern: str, optional
            Pattern to split cell barcode from sample id. Default: ___ .
    use_polars: bool, optional
            Whether to use polars to read fragments files. Default: True.
    **kwargs
            Additional parameters for ray.init()
    Return
    ------
    dict
            A dictionary containing the paths to the newly created bed fragments files per group a dictionary containing the paths to the
            newly created bigwig files per group.
    """
    # Create logger
    level = logging.INFO
    log_format = "%(asctime)s %(name)-12s %(levelname)-8s %(message)s"
    handlers = [logging.StreamHandler(stream=sys.stdout)]
    logging.basicConfig(level=level, format=log_format, handlers=handlers)
    log = logging.getLogger("cisTopic")

    # Get fragments file
    if isinstance(input_data, CistopicObject):
        path_to_fragments = input_data.path_to_fragments
        if path_to_fragments is None:
            log.error("No path_to_fragments in this cisTopic object.")
        cell_data = input_data.cell_data
    elif isinstance(input_data, pd.DataFrame):
        if path_to_fragments is None:
            log.error("Please, provide path_to_fragments.")
        cell_data = input_data
    # Check for sample_id column
    try:
        sample_ids = list(set(cell_data[sample_id_col]))
    except ValueError:
        print(
            'Please, include a sample identification column (e.g. "sample_id") in your cell metadata!'
        )

    # Get fragments
    #fragments_df_dict = {}
    """
    for sample_id in path_to_fragments.keys():
        if sample_id not in sample_ids:
            log.info(
                "The following path_to_fragments entry is not found in the cell metadata sample_id_col: ",
                sample_id,
                ". It will be ignored.",
            )
        else:
            log.info("Reading fragments from " + path_to_fragments[sample_id])
            fragments_df = read_fragments_from_file(path_to_fragments[sample_id], use_polars=use_polars).df
            # Convert to int32 for memory efficiency
            fragments_df.Start = np.int32(fragments_df.Start)
            fragments_df.End = np.int32(fragments_df.End)
            if "Score" in fragments_df:
                fragments_df.Score = np.int32(fragments_df.Score)
            if "barcode" in cell_data:
                fragments_df = fragments_df.loc[
                    fragments_df["Name"].isin(cell_data["barcode"].tolist())
                ]
            else:
                fragments_df = fragments_df.loc[
                    fragments_df["Name"].isin(
                        prepare_tag_cells(cell_data.index.tolist(), split_pattern)
                    )
                ]
            fragments_df_dict[sample_id] = fragments_df
    """
    
    # Set groups
    if "barcode" in cell_data:
        cell_data = cell_data.loc[:, [variable, sample_id_col, "barcode"]]
    else:
        cell_data = cell_data.loc[:, [variable, sample_id_col]]
    cell_data[variable] = cell_data[variable].replace(" ", "", regex=True)
    cell_data[variable] = cell_data[variable].replace("[^A-Za-z0-9]+", "_", regex=True)
    groups = sorted(list(set(cell_data[variable])))
    groups = groups[:2]
    print(groups)
    # Check chromosome sizes
    if isinstance(chromsizes, pd.DataFrame):
        chromsizes = chromsizes.loc[:, ["Chromosome", "Start", "End"]]
        chromsizes = pr.PyRanges(chromsizes)
    # Check that output dir exist and generate output paths
    if isinstance(bed_path, str):
        if not os.path.exists(bed_path):
            os.makedirs(bed_path)
        bed_paths = {
            group: os.path.join(bed_path, str(group) + ".bed.gz") for group in groups
        }
    else:
        bed_paths = {}
    if isinstance(bigwig_path, str):
        if not os.path.exists(bigwig_path):
            os.makedirs(bigwig_path)
        bw_paths = {
            group: os.path.join(bigwig_path, str(group) + ".bw") for group in groups
        }
    else:
        bw_paths = {}
    # Create pseudobulks
    print(cell_data)
    print(groups)
    print(fragments_df_dict)
    print(chromsizes)
    print(bigwig_path, bed_path)
    print(sample_id_col)
    if n_cpu > 1:
        ray.init(num_cpus=n_cpu, **kwargs)
        ray_handle = ray.wait(
            [
                export_pseudobulk_ray.remote(
                    cell_data,
                    group,
                    fragments_df_dict,
                    chromsizes,
                    bigwig_path,
                    bed_path,
                    sample_id_col,
                    normalize_bigwig,
                    remove_duplicates,
                    split_pattern,
                )
                for group in groups
            ],
            num_returns=len(groups),
        )
        ray.shutdown()
    else:
        [
            export_pseudobulk_one_sample(
                cell_data,
                group,
                fragments_df_dict,
                chromsizes,
                bigwig_path,
                bed_path,
                sample_id_col,
                normalize_bigwig,
                remove_duplicates,
                split_pattern,
            )
            for group in groups
        ]

    return bw_paths, bed_paths

# %%
bw_paths, bed_paths = export_pseudobulk(
    input_data = test_cell_data,
    variable = 'celltypes', # variable by which to generate pseubulk profiles, in this case we want pseudobulks per celltype
    sample_id_col = 'sample_id',
    chromsizes = chromsizes,
    bed_path = os.path.join(work_dir, 'scATAC/consensus_peak_calling/pseudobulk_bed_files/'),  # specify where pseudobulk_bed_files should be stored
    bigwig_path = os.path.join(work_dir, 'scATAC/consensus_peak_calling/pseudobulk_bw_files/'), # specify where pseudobulk_bw_files should be stored
    path_to_fragments = test_fragments_dict, # location of fragment fiels
    n_cpu = 1, # specify the number of cores to use, we use ray for multi processing
    normalize_bigwig = True,
    remove_duplicates = True,
    _temp_dir = os.path.join(tmp_dir, 'ray_spill'),
    split_pattern = '-'
)

# %%
from pycisTopic.pseudobulk_peak_calling import export_pseudobulk
bw_paths, bed_paths = export_pseudobulk(
    input_data = cell_data,
    variable = 'celltype', # variable by which to generate pseubulk profiles, in this case we want pseudobulks per celltype
    sample_id_col = 'sample_id',
    chromsizes = chromsizes,
    bed_path = os.path.join(work_dir, 'scATAC/consensus_peak_calling/pseudobulk_bed_files/'),  # specify where pseudobulk_bed_files should be stored
    bigwig_path = os.path.join(work_dir, 'scATAC/consensus_peak_calling/pseudobulk_bw_files/'), # specify where pseudobulk_bw_files should be stored
    path_to_fragments = fragments_dict, # location of fragment fiels
    n_cpu = 12, # specify the number of cores to use, we use ray for multi processing
    normalize_bigwig = True,
    remove_duplicates = True,
    _temp_dir = os.path.join(tmp_dir, 'ray_spill'),
    split_pattern = '-'
)

# %%
import logging

# %%
path_to_fragments = test_fragments_dict
sample_id_col = "sample_id"
variable = "celltypes"
sample_ids = list(set(cell_data[sample_id_col]))
use_polars = True
level = logging.INFO
log_format = "%(asctime)s %(name)-12s %(levelname)-8s %(message)s"
handlers = [logging.StreamHandler(stream=sys.stdout)]
logging.basicConfig(level=level, format=log_format, handlers=handlers)
log = logging.getLogger("cisTopic")
cell_data = test_cell_data
bed_path = os.path.join(work_dir, 'scATAC/consensus_peak_calling/pseudobulk_bed_files/')
bigwig_path = os.path.join(work_dir, 'scATAC/consensus_peak_calling/pseudobulk_bw_files/'),

# %%
from pycisTopic.utils import read_fragments_from_file, prepare_tag_cells

# %%
import numpy as np

# %%
fragments_df_dict = {}
for sample_id in path_to_fragments.keys():
    if sample_id not in sample_ids:
        log.info(
            "The following path_to_fragments entry is not found in the cell metadata sample_id_col: ",
            sample_id,
            ". It will be ignored.",
        )
    else:
        log.info("Reading fragments from " + path_to_fragments[sample_id])

        fragments_df = read_fragments_from_file(path_to_fragments[sample_id], use_polars=use_polars).df
        # Convert to int32 for memory efficiency
        fragments_df.Start = np.int32(fragments_df.Start)
        fragments_df.End = np.int32(fragments_df.End)
        if "Score" in fragments_df:
            fragments_df.Score = np.int32(fragments_df.Score)
        if "barcode" in cell_data:
            fragments_df = fragments_df.loc[
                fragments_df["Name"].isin(cell_data["barcode"].tolist())
            ]
        else:
            fragments_df = fragments_df.loc[
                fragments_df["Name"].isin(
                    prepare_tag_cells(cell_data.index.tolist(), split_pattern)
                )
            ]
        fragments_df_dict[sample_id] = fragments_df

# %%
if "barcode" in cell_data:
    cell_data = cell_data.loc[:, [variable, sample_id_col, "barcode"]]
else:
    cell_data = cell_data.loc[:, [variable, sample_id_col]]
cell_data[variable] = cell_data[variable].replace(" ", "", regex=True)
cell_data[variable] = cell_data[variable].replace("[^A-Za-z0-9]+", "_", regex=True)
groups = sorted(list(set(cell_data[variable])))

# %%
cell_data

# %%
group = groups[0]

# %%
level = logging.INFO
log_format = "%(asctime)s %(name)-12s %(levelname)-8s %(message)s"
handlers = [logging.StreamHandler(stream=sys.stdout)]
logging.basicConfig(level=level, format=log_format, handlers=handlers)
log = logging.getLogger("cisTopic")

log.info("Creating pseudobulk for " + str(group))
group_fragments_list = []
group_fragments_dict = {}

# %%
log.info("Creating pseudobulk for " + str(group))
group_fragments_list = []
group_fragments_dict = {}
for sample_id in fragments_df_dict:
    print(sample_id)
    sample_data = cell_data[cell_data.loc[:, sample_id_col].isin([sample_id])]
    if "barcode" in sample_data:
        sample_data.index = sample_data["barcode"].tolist()
    else:
        sample_data.index = prepare_tag_cells(
            sample_data.index.tolist(), split_pattern
        )
    group_var = sample_data.iloc[:, 0]
    barcodes = group_var[group_var.isin([group])].index.tolist()
    fragments_df = fragments_df_dict[sample_id]
    group_fragments = fragments_df.loc[fragments_df["Name"].isin(barcodes)]
    if len(fragments_df_dict) > 1:
        group_fragments_dict[sample_id] = group_fragments

# %%
sample_data

# %%
sample_data = cell_data[cell_data.loc[:, sample_id_col].isin([sample_id])]

# %%
if len(fragments_df_dict) > 1:
        group_fragments_list = [
            group_fragments_dict[list(group_fragments_dict.keys())[x]]
            for x in range(len(fragments_df_dict))
        ]
        group_fragments = group_fragments_list[0].append(group_fragments_list[1:])

# %%
del group_fragments_dict
del group_fragments_list
del fragments_df
gc.collect()

group_pr = pr.PyRanges(group_fragments)

# %%
group_pr

# %%
if isinstance(bigwig_path, str):
    bigwig_path_group = os.path.join(bigwig_path, str(group) + ".bw")
    if remove_duplicates:
        group_pr.to_bigwig(
            path=bigwig_path_group,
            chromosome_sizes=chromsizes,
            rpm=normalize_bigwig,
        )
    else:
        group_pr.to_bigwig(
            path=bigwig_path_group,
            chromosome_sizes=chromsizes,
            rpm=normalize_bigwig,
            value_col="Score",
        )
if isinstance(bed_path, str):
    print("here")
    print(group_pr)
    bed_path_group = os.path.join(bed_path, str(group) + ".bed.gz")
    group_pr.to_bed(
        path=bed_path_group, keep=False, compression="infer", chain=False
    )

log.info(str(group) + " done!")

# %%
import gc
import logging
import os
import re
import subprocess
import sys
from typing import Dict, List, Optional, Union
import numpy as np
import pandas as pd
import pyBigWig
import pyranges as pr

def export_pseudobulk_one_sample(
    cell_data: pd.DataFrame,
    group: str,
    fragments_df_dict: Dict[str, pd.DataFrame],
    chromsizes: pr.PyRanges,
    bigwig_path: str,
    bed_path: str,
    sample_id_col: Optional[str] = "sample_id",
    normalize_bigwig: Optional[bool] = True,
    remove_duplicates: Optional[bool] = True,
    split_pattern: Optional[str] = "___",
):
    """
    Create pseudobulk as bed and bigwig from single cell fragments file given a barcode annotation and a group.
    Parameters
    ---------
    cell_data: pd.DataFrame
            A cell metadata :class:`pd.Dataframe` containing barcodes, their annotation and their sample of origin.
    group: str
            A character string indicating the group for which pseudobulks will be created.
    fragments_df_dict: dict
            A dictionary containing data frames as values with 'Chromosome', 'Start', 'End', 'Name', and 'Score' as columns; and sample label
            as keys. 'Score' indicates the number of times that a fragments is found assigned to that barcode.
    chromsizes: pr.PyRanges
            A :class:`pr.PyRanges` containing size of each column, containing 'Chromosome', 'Start' and 'End' columns.
    bigwig_path: str
            Path to folder where the bigwig file will be saved.
    bed_path: str
            Path to folder where the fragments bed file will be saved.
    sample_id_col: str, optional
            Name of the column containing the sample name per barcode in the input :class:`CistopicObject.cell_data` or class:`pd.DataFrame`. Default: 'sample_id'.
    normalize_bigwig: bool, optional
            Whether bigwig files should be CPM normalized. Default: True.
    remove_duplicates: bool, optional
            Whether duplicates should be removed before converting the data to bigwig.
    split_pattern: str
            Pattern to split cell barcode from sample id. Default: ___ .
    """
    # Create logger
    level = logging.INFO
    log_format = "%(asctime)s %(name)-12s %(levelname)-8s %(message)s"
    handlers = [logging.StreamHandler(stream=sys.stdout)]
    logging.basicConfig(level=level, format=log_format, handlers=handlers)
    log = logging.getLogger("cisTopic")

    log.info("Creating pseudobulk for " + str(group))
    group_fragments_list = []
    group_fragments_dict = {}
    for sample_id in fragments_df_dict:
        sample_data = cell_data[cell_data.loc[:, sample_id_col].isin([sample_id])]
        if "barcode" in sample_data:
            sample_data.index = sample_data["barcode"].tolist()
        else:
            sample_data.index = prepare_tag_cells(
                sample_data.index.tolist(), split_pattern
            )
        group_var = sample_data.iloc[:, 0]
        barcodes = group_var[group_var.isin([group])].index.tolist()
        fragments_df = fragments_df_dict[sample_id]
        group_fragments = fragments_df.loc[fragments_df["Name"].isin(barcodes)]
        if len(fragments_df_dict) > 1:
            group_fragments_dict[sample_id] = group_fragments

    if len(fragments_df_dict) > 1:
        group_fragments_list = [
            group_fragments_dict[list(group_fragments_dict.keys())[x]]
            for x in range(len(fragments_df_dict))
        ]
        group_fragments = group_fragments_list[0].append(group_fragments_list[1:])

    del group_fragments_dict
    del group_fragments_list
    del fragments_df
    gc.collect()

    group_pr = pr.PyRanges(group_fragments)
    if isinstance(bigwig_path, str):
        bigwig_path_group = os.path.join(bigwig_path, str(group) + ".bw")
        if remove_duplicates:
            group_pr.to_bigwig(
                path=bigwig_path_group,
                chromosome_sizes=chromsizes,
                rpm=normalize_bigwig,
            )
        else:
            group_pr.to_bigwig(
                path=bigwig_path_group,
                chromosome_sizes=chromsizes,
                rpm=normalize_bigwig,
                value_col="Score",
            )
    if isinstance(bed_path, str):
        print("here")
        print(group_pr)
        bed_path_group = os.path.join(bed_path, str(group) + ".bed.gz")
        group_pr.to_bed(
            path=bed_path_group, keep=False, compression="infer", chain=False
        )

    log.info(str(group) + " done!")

# %%
sample_data

# %%
fragments_df_dict["ENCFF187VMN"]

# %%
export_pseudobulk_one_sample(
    cell_data,
    groups[2],
    fragments_df_dict,
    chromsizes,
    bigwig_path,
    bed_path,
    sample_id_col,
    True,
    True,
    "-"
)

# %%
test = [
export_pseudobulk_one_sample(
    cell_data,
    group,
    fragments_df_dict,
    chromsizes,
    bigwig_path,
    bed_path,
    sample_id_col,
    True,
    True,
    "-",
)
for group in groups
]

# %%
from pycisTopic.pseudobulk_peak_calling import export_pseudobulk
bw_paths, bed_paths = export_pseudobulk(
    input_data = test_cell_data,
    variable = 'celltypes', # variable by which to generate pseubulk profiles, in this case we want pseudobulks per celltype
    sample_id_col = 'sample_id',
    chromsizes = chromsizes,
    bed_path = os.path.join(work_dir, 'scATAC/consensus_peak_calling/pseudobulk_bed_files/'),  # specify where pseudobulk_bed_files should be stored
    bigwig_path = os.path.join(work_dir, 'scATAC/consensus_peak_calling/pseudobulk_bw_files/'), # specify where pseudobulk_bw_files should be stored
    path_to_fragments = test_fragments_dict, # location of fragment fiels
    n_cpu = 1, # specify the number of cores to use, we use ray for multi processing
    normalize_bigwig = True,
    remove_duplicates = True,
    _temp_dir = os.path.join(tmp_dir, 'ray_spill'),
    split_pattern = '-'
)
